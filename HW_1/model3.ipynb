# %% [markdown]
# # EfficientNetV2S

# %% [markdown]
# ## 🌐 Connect Colab to Google Drive

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/MyDrive/[2024-2025] AN2DL/Homework 1
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/[2024-2025] AN2DL/Homework 1

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Set the global policy for mixed precision (16/32-bit float)
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
from PIL import Image
import matplotlib.gridspec as gridspec

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data
data = np.load('filtered_data.npz')
X = data['images']
y = data['labels']

# %%
# Display a sample of images from the training-validation dataset
num_img = 10
random.seed(10)
random_indices = random.sample(range(len(X)), num_img)

fig, axes = plt.subplots(1, num_img, figsize=(20, 20))

# Iterate through the selected number of images
for i, idx in enumerate(random_indices):
    ax = axes[i % num_img]
    ax.imshow(np.squeeze(X[idx]), vmin=0., vmax=1.)
    ax.set_title(f'{y[idx]}')
    ax.axis('off')

# Adjust layout and display the images
plt.tight_layout()
plt.show()

# %%
# Inspect the target
print('Counting occurrences of target classes:')
print(pd.DataFrame(y, columns=['digit'])['digit'].value_counts())
# Out:
# Counting occurrences of target classes:
# digit
# 6    2330
# 1    2181
# 3    2026
# 7    1643
# 2    1085
# 5     993
# 0     852
# 4     849
# Name: count, dtype: int64

# %%
# WITHOUT A TEST SET

# Convert labels to categorical format using one-hot encoding
y = tfk.utils.to_categorical(y)

from tensorflow.keras.utils import to_categorical

# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=seed, test_size=0.1, stratify=y)

# Numero di classi nel dataset
num_classes = len(np.unique(y))  # Ad esempio, 8 classi

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (10763, 96, 96, 3)
# Training Label Shape: (10763, 8)
# Validation Data Shape: (1196, 96, 96, 3)
# Validation Label Shape: (1196, 8)

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8

# %%
# Number of training epochs
epochs = 500

# Batch size for training
batch_size = 1024

# Learning rate: step size for updating the model's weights
learning_rate = 5e-4

# Print the defined parameters
print("Epochs:", epochs)
print("Batch Size:", batch_size)
print("Learning Rare:", learning_rate)
# Out:
# Epochs: 500
# Batch Size: 1024
# Learning Rare: 0.0005

# %%
# Initialise MobileNetV3Small model with pretrained weights, for transfer learning
net = tfk.applications.EfficientNetV2B3(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=input_shape,
    pooling='max',
    classifier_activation="softmax",
    include_preprocessing=True,
    name="efficientnetv2-b3",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Freeze all layers in EfficientNetB0 to use it solely as a feature extractor
net.trainable = False

# Apply data augmentation for training robustness
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(1),
    tfkl.RandomZoom(0.05),
    tfkl.RandomContrast(0.25),
], name='preprocessing')

# %%
import tensorflow as tf
from tensorflow.keras import layers as tfkl, models as tfk, losses, optimizers, initializers, regularizers
from tensorflow.keras.layers import Resizing

def build_model(
    input_shape,
    output_shape,
    learning_rate,
    seed,
    augmentation=None, # Add augmentation as an optional parameter
    l2_lambda=5e-2
):
    tf.random.set_seed(seed)

    # Define the input layer
    inputs = tfkl.Input(shape=input_shape, name='Input')

    # Apply augmentation if provided (use a dictionary format for MixUp)
    if augmentation:
        x = augmentation(inputs)
    else:
        x = inputs

    # Weight initialization and regularization
    initializer = initializers.HeNormal(seed=seed)
    regularizer = regularizers.l2(l2_lambda)

    # Pass augmented inputs through the network feature extractor
    x = net(x)

    # Fully Connected Layers
    x = tfkl.Dense(64, kernel_initializer=initializer, kernel_regularizer=regularizer)(x)
    x = tfkl.BatchNormalization(beta_regularizer=regularizer)(x)
    x = tfkl.Activation('relu')(x)

    # Output Layer
    outputs = tfkl.Dense(output_shape, kernel_initializer=initializer, kernel_regularizer=regularizer, activation='softmax', dtype='float32', name='output')(x)

    model = tfk.Model(inputs=inputs, outputs=outputs, name='CNN')

    # Corrected loss and optimizer imports
    loss = losses.CategoricalCrossentropy()
    optimizer = tf.keras.optimizers.Lion(learning_rate = 5e-4)
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    return model

# %%
from sklearn.utils import class_weight
import numpy as np

# If y_train is one-hot encoded, convert it to integer labels
if len(y_train.shape) > 1:
  y_train_int = np.argmax(y_train, axis=1)  # Converts one-hot to integer labels


# Compute class weights
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train_int),
    y=y_train_int
)

# Convert the result into a dictionary
class_weight_dict = dict(enumerate(class_weights))

# %%
# Build the model with specified input and output shapes
model = build_model(input_shape=input_shape, output_shape=output_shape, learning_rate=learning_rate, seed=seed, augmentation=augmentation)

# Display a summary of the model architecture
model.summary(expand_nested=False, show_trainable=True)

# Plot the model architecture with the correct import
# plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ cast_1 (Cast)                       │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ preprocessing (Sequential)          │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ efficientnetv2-b3 (Functional)      │ (None, 1536)                 │    12,930,622 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 64)                   │        98,368 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ batch_normalization                 │ (None, 64)                   │           256 │    Y    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation (Activation)             │ (None, 64)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ cast_2 (Cast)                       │ (None, 64)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ output (Dense)                      │ (None, 8)                    │           520 │    Y    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 13,029,766 (49.70 MB)
#  Trainable params: 99,016 (386.78 KB)
#  Non-trainable params: 12,930,750 (49.33 MB)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping  # Import EarlyStopping directly
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define the patience value for early stopping
patience = 30

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Metric to monitor
    factor=0.2,          # Factor to reduce learning rate by (0.1 means divide by 10)
    patience=5,          # Number of epochs to wait before reducing
    min_lr=1e-5       # Minimum learning rate
)

# Create an EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [reduce_lr,early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks,
    class_weight=class_weight_dict,
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'NoPainNoTrain'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.2128 - loss: 9.0949 - val_accuracy: 0.4289 - val_loss: 7.7178 - learning_rate: 5.0000e-04
# Epoch 2/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 453ms/step - accuracy: 0.4971 - loss: 7.2124 - val_accuracy: 0.6087 - val_loss: 6.1958 - learning_rate: 5.0000e-04
# Epoch 3/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.6380 - loss: 5.8522 - val_accuracy: 0.7074 - val_loss: 4.9903 - learning_rate: 5.0000e-04
# Epoch 4/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 469ms/step - accuracy: 0.7175 - loss: 4.7524 - val_accuracy: 0.7584 - val_loss: 4.0367 - learning_rate: 5.0000e-04
# Epoch 5/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 465ms/step - accuracy: 0.7536 - loss: 3.8855 - val_accuracy: 0.7952 - val_loss: 3.3187 - learning_rate: 5.0000e-04
# Epoch 6/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 448ms/step - accuracy: 0.7754 - loss: 3.2030 - val_accuracy: 0.8043 - val_loss: 2.8006 - learning_rate: 5.0000e-04
# Epoch 7/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - accuracy: 0.7995 - loss: 2.6743 - val_accuracy: 0.8085 - val_loss: 2.4531 - learning_rate: 5.0000e-04
# Epoch 8/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 455ms/step - accuracy: 0.8144 - loss: 2.2877 - val_accuracy: 0.8211 - val_loss: 2.2388 - learning_rate: 5.0000e-04
# Epoch 9/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 469ms/step - accuracy: 0.8219 - loss: 2.0132 - val_accuracy: 0.8286 - val_loss: 2.1135 - learning_rate: 5.0000e-04
# Epoch 10/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - accuracy: 0.8289 - loss: 1.8353 - val_accuracy: 0.8278 - val_loss: 2.0705 - learning_rate: 5.0000e-04
# Epoch 11/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - accuracy: 0.8398 - loss: 1.7007 - val_accuracy: 0.8077 - val_loss: 2.0464 - learning_rate: 5.0000e-04
# Epoch 12/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.8436 - loss: 1.6361 - val_accuracy: 0.8729 - val_loss: 2.0020 - learning_rate: 5.0000e-04
# Epoch 13/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step - accuracy: 0.8461 - loss: 1.5893 - val_accuracy: 0.8687 - val_loss: 2.0008 - learning_rate: 5.0000e-04
# Epoch 14/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 485ms/step - accuracy: 0.8435 - loss: 1.5702 - val_accuracy: 0.8963 - val_loss: 1.9528 - learning_rate: 5.0000e-04
# Epoch 15/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 464ms/step - accuracy: 0.8473 - loss: 1.5599 - val_accuracy: 0.8771 - val_loss: 1.9212 - learning_rate: 5.0000e-04
# Epoch 16/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 448ms/step - accuracy: 0.8451 - loss: 1.5391 - val_accuracy: 0.8804 - val_loss: 1.8585 - learning_rate: 5.0000e-04
# Epoch 17/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 457ms/step - accuracy: 0.8533 - loss: 1.5132 - val_accuracy: 0.8955 - val_loss: 1.7800 - learning_rate: 5.0000e-04
# Epoch 18/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - accuracy: 0.8508 - loss: 1.4755 - val_accuracy: 0.8645 - val_loss: 1.7257 - learning_rate: 5.0000e-04
# Epoch 19/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 453ms/step - accuracy: 0.8496 - loss: 1.4306 - val_accuracy: 0.8604 - val_loss: 1.6705 - learning_rate: 5.0000e-04
# Epoch 20/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 455ms/step - accuracy: 0.8576 - loss: 1.3397 - val_accuracy: 0.8930 - val_loss: 1.5445 - learning_rate: 5.0000e-04
# Epoch 21/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 483ms/step - accuracy: 0.8447 - loss: 1.2837 - val_accuracy: 0.8972 - val_loss: 1.4524 - learning_rate: 5.0000e-04
# Epoch 22/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 440ms/step - accuracy: 0.8493 - loss: 1.1870 - val_accuracy: 0.8921 - val_loss: 1.3686 - learning_rate: 5.0000e-04
# Epoch 23/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 444ms/step - accuracy: 0.8538 - loss: 1.0958 - val_accuracy: 0.8696 - val_loss: 1.3531 - learning_rate: 5.0000e-04
# Epoch 24/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - accuracy: 0.8505 - loss: 1.0280 - val_accuracy: 0.8679 - val_loss: 1.3267 - learning_rate: 5.0000e-04
# Epoch 25/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 459ms/step - accuracy: 0.8420 - loss: 1.0022 - val_accuracy: 0.8855 - val_loss: 1.2675 - learning_rate: 5.0000e-04
# Epoch 26/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.8455 - loss: 0.9639 - val_accuracy: 0.8545 - val_loss: 1.1951 - learning_rate: 5.0000e-04
# Epoch 27/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 459ms/step - accuracy: 0.8463 - loss: 0.9363 - val_accuracy: 0.8838 - val_loss: 1.1734 - learning_rate: 5.0000e-04
# Epoch 28/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 459ms/step - accuracy: 0.8462 - loss: 0.9244 - val_accuracy: 0.8645 - val_loss: 1.1480 - learning_rate: 5.0000e-04
# Epoch 29/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 470ms/step - accuracy: 0.8447 - loss: 0.9149 - val_accuracy: 0.8662 - val_loss: 1.1157 - learning_rate: 5.0000e-04
# Epoch 30/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 467ms/step - accuracy: 0.8491 - loss: 0.8937 - val_accuracy: 0.9038 - val_loss: 1.0559 - learning_rate: 5.0000e-04
# Epoch 31/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 441ms/step - accuracy: 0.8442 - loss: 0.8958 - val_accuracy: 0.8821 - val_loss: 1.0077 - learning_rate: 5.0000e-04
# Epoch 32/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 471ms/step - accuracy: 0.8448 - loss: 0.8820 - val_accuracy: 0.8863 - val_loss: 0.9997 - learning_rate: 5.0000e-04
# Epoch 33/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 465ms/step - accuracy: 0.8480 - loss: 0.8691 - val_accuracy: 0.8562 - val_loss: 0.9547 - learning_rate: 5.0000e-04
# Epoch 34/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 443ms/step - accuracy: 0.8502 - loss: 0.8488 - val_accuracy: 0.8671 - val_loss: 0.9836 - learning_rate: 5.0000e-04
# Epoch 35/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 470ms/step - accuracy: 0.8441 - loss: 0.8428 - val_accuracy: 0.8946 - val_loss: 0.9242 - learning_rate: 5.0000e-04
# Epoch 36/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 481ms/step - accuracy: 0.8487 - loss: 0.8389 - val_accuracy: 0.9072 - val_loss: 0.8387 - learning_rate: 5.0000e-04
# Epoch 37/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 455ms/step - accuracy: 0.8537 - loss: 0.8194 - val_accuracy: 0.8779 - val_loss: 0.8805 - learning_rate: 5.0000e-04
# Epoch 38/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 463ms/step - accuracy: 0.8464 - loss: 0.8268 - val_accuracy: 0.9030 - val_loss: 0.8011 - learning_rate: 5.0000e-04
# Epoch 39/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 468ms/step - accuracy: 0.8426 - loss: 0.8119 - val_accuracy: 0.8386 - val_loss: 0.9028 - learning_rate: 5.0000e-04
# Epoch 40/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 461ms/step - accuracy: 0.8448 - loss: 0.8133 - val_accuracy: 0.8679 - val_loss: 0.8123 - learning_rate: 5.0000e-04
# Epoch 41/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - accuracy: 0.8454 - loss: 0.8166 - val_accuracy: 0.8487 - val_loss: 0.8439 - learning_rate: 5.0000e-04
# Epoch 42/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 454ms/step - accuracy: 0.8471 - loss: 0.8054 - val_accuracy: 0.8654 - val_loss: 0.8124 - learning_rate: 5.0000e-04
# Epoch 43/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 459ms/step - accuracy: 0.8496 - loss: 0.7950 - val_accuracy: 0.8629 - val_loss: 0.7919 - learning_rate: 5.0000e-04
# Epoch 44/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 463ms/step - accuracy: 0.8425 - loss: 0.7975 - val_accuracy: 0.8629 - val_loss: 0.7951 - learning_rate: 5.0000e-04
# Epoch 45/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - accuracy: 0.8422 - loss: 0.7974 - val_accuracy: 0.8829 - val_loss: 0.7629 - learning_rate: 5.0000e-04
# Epoch 46/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 459ms/step - accuracy: 0.8454 - loss: 0.7825 - val_accuracy: 0.8754 - val_loss: 0.7406 - learning_rate: 5.0000e-04
# Epoch 47/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 469ms/step - accuracy: 0.8464 - loss: 0.7849 - val_accuracy: 0.8629 - val_loss: 0.7529 - learning_rate: 5.0000e-04
# Epoch 48/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 443ms/step - accuracy: 0.8450 - loss: 0.7867 - val_accuracy: 0.8436 - val_loss: 0.7603 - learning_rate: 5.0000e-04
# Epoch 49/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - accuracy: 0.8428 - loss: 0.7789 - val_accuracy: 0.8696 - val_loss: 0.7533 - learning_rate: 5.0000e-04
# Epoch 50/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - accuracy: 0.8450 - loss: 0.7791 - val_accuracy: 0.9038 - val_loss: 0.6705 - learning_rate: 5.0000e-04
# Epoch 51/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 450ms/step - accuracy: 0.8430 - loss: 0.7922 - val_accuracy: 0.8972 - val_loss: 0.6565 - learning_rate: 5.0000e-04
# Epoch 52/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 463ms/step - accuracy: 0.8529 - loss: 0.7534 - val_accuracy: 0.8963 - val_loss: 0.6755 - learning_rate: 5.0000e-04
# Epoch 53/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - accuracy: 0.8436 - loss: 0.7704 - val_accuracy: 0.8829 - val_loss: 0.6939 - learning_rate: 5.0000e-04
# Epoch 54/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 470ms/step - accuracy: 0.8455 - loss: 0.7669 - val_accuracy: 0.8637 - val_loss: 0.7104 - learning_rate: 5.0000e-04
# Epoch 55/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 462ms/step - accuracy: 0.8389 - loss: 0.7796 - val_accuracy: 0.8411 - val_loss: 0.7825 - learning_rate: 5.0000e-04
# Epoch 56/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.8471 - loss: 0.7600 - val_accuracy: 0.8512 - val_loss: 0.7156 - learning_rate: 5.0000e-04
# Epoch 57/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 443ms/step - accuracy: 0.8507 - loss: 0.7531 - val_accuracy: 0.8804 - val_loss: 0.6857 - learning_rate: 1.0000e-04
# Epoch 58/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 464ms/step - accuracy: 0.8528 - loss: 0.7336 - val_accuracy: 0.8737 - val_loss: 0.7022 - learning_rate: 1.0000e-04
# Epoch 59/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 450ms/step - accuracy: 0.8571 - loss: 0.7151 - val_accuracy: 0.8829 - val_loss: 0.6888 - learning_rate: 1.0000e-04
# Epoch 60/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 464ms/step - accuracy: 0.8604 - loss: 0.7034 - val_accuracy: 0.8871 - val_loss: 0.6777 - learning_rate: 1.0000e-04
# Epoch 61/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 477ms/step - accuracy: 0.8662 - loss: 0.6895 - val_accuracy: 0.8712 - val_loss: 0.7198 - learning_rate: 1.0000e-04
# Epoch 62/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - accuracy: 0.8692 - loss: 0.6714 - val_accuracy: 0.8796 - val_loss: 0.7025 - learning_rate: 2.0000e-05
# Epoch 63/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.8680 - loss: 0.6755 - val_accuracy: 0.8921 - val_loss: 0.6766 - learning_rate: 2.0000e-05
# Epoch 64/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 466ms/step - accuracy: 0.8660 - loss: 0.6753 - val_accuracy: 0.8980 - val_loss: 0.6607 - learning_rate: 2.0000e-05
# Epoch 65/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 464ms/step - accuracy: 0.8669 - loss: 0.6718 - val_accuracy: 0.9055 - val_loss: 0.6380 - learning_rate: 2.0000e-05
# Epoch 66/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 457ms/step - accuracy: 0.8627 - loss: 0.6830 - val_accuracy: 0.9114 - val_loss: 0.6204 - learning_rate: 2.0000e-05
# Epoch 67/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 471ms/step - accuracy: 0.8694 - loss: 0.6560 - val_accuracy: 0.9130 - val_loss: 0.6075 - learning_rate: 2.0000e-05
# Epoch 68/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 465ms/step - accuracy: 0.8735 - loss: 0.6556 - val_accuracy: 0.9147 - val_loss: 0.5991 - learning_rate: 2.0000e-05
# Epoch 69/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 464ms/step - accuracy: 0.8667 - loss: 0.6600 - val_accuracy: 0.9172 - val_loss: 0.5962 - learning_rate: 2.0000e-05
# Epoch 70/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - accuracy: 0.8681 - loss: 0.6602 - val_accuracy: 0.9156 - val_loss: 0.6025 - learning_rate: 2.0000e-05
# Epoch 71/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 457ms/step - accuracy: 0.8731 - loss: 0.6571 - val_accuracy: 0.9097 - val_loss: 0.6155 - learning_rate: 2.0000e-05
# Epoch 72/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 466ms/step - accuracy: 0.8744 - loss: 0.6547 - val_accuracy: 0.9089 - val_loss: 0.6164 - learning_rate: 2.0000e-05
# Epoch 73/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 449ms/step - accuracy: 0.8714 - loss: 0.6414 - val_accuracy: 0.9072 - val_loss: 0.6071 - learning_rate: 2.0000e-05
# Epoch 74/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 443ms/step - accuracy: 0.8753 - loss: 0.6464 - val_accuracy: 0.9097 - val_loss: 0.6095 - learning_rate: 2.0000e-05
# Epoch 75/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 468ms/step - accuracy: 0.8702 - loss: 0.6450 - val_accuracy: 0.9105 - val_loss: 0.6042 - learning_rate: 1.0000e-05
# Epoch 76/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 441ms/step - accuracy: 0.8778 - loss: 0.6315 - val_accuracy: 0.9097 - val_loss: 0.6019 - learning_rate: 1.0000e-05
# Epoch 77/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 468ms/step - accuracy: 0.8755 - loss: 0.6287 - val_accuracy: 0.9097 - val_loss: 0.6005 - learning_rate: 1.0000e-05
# Epoch 78/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 465ms/step - accuracy: 0.8785 - loss: 0.6399 - val_accuracy: 0.9064 - val_loss: 0.5985 - learning_rate: 1.0000e-05
# Epoch 79/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.8741 - loss: 0.6430 - val_accuracy: 0.9072 - val_loss: 0.6000 - learning_rate: 1.0000e-05
# Epoch 80/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.8743 - loss: 0.6413 - val_accuracy: 0.9064 - val_loss: 0.5992 - learning_rate: 1.0000e-05
# Epoch 81/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 444ms/step - accuracy: 0.8744 - loss: 0.6393 - val_accuracy: 0.9089 - val_loss: 0.5948 - learning_rate: 1.0000e-05
# Epoch 82/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 467ms/step - accuracy: 0.8780 - loss: 0.6309 - val_accuracy: 0.9080 - val_loss: 0.5921 - learning_rate: 1.0000e-05
# Epoch 83/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 447ms/step - accuracy: 0.8731 - loss: 0.6346 - val_accuracy: 0.9038 - val_loss: 0.5952 - learning_rate: 1.0000e-05
# Epoch 84/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - accuracy: 0.8749 - loss: 0.6274 - val_accuracy: 0.9013 - val_loss: 0.5943 - learning_rate: 1.0000e-05
# Epoch 85/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 462ms/step - accuracy: 0.8727 - loss: 0.6333 - val_accuracy: 0.9013 - val_loss: 0.5970 - learning_rate: 1.0000e-05
# Epoch 86/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 442ms/step - accuracy: 0.8718 - loss: 0.6378 - val_accuracy: 0.9030 - val_loss: 0.5921 - learning_rate: 1.0000e-05
# Epoch 87/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 467ms/step - accuracy: 0.8777 - loss: 0.6302 - val_accuracy: 0.9064 - val_loss: 0.5885 - learning_rate: 1.0000e-05
# Epoch 88/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 463ms/step - accuracy: 0.8765 - loss: 0.6298 - val_accuracy: 0.9064 - val_loss: 0.5860 - learning_rate: 1.0000e-05
# Epoch 89/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 461ms/step - accuracy: 0.8805 - loss: 0.6211 - val_accuracy: 0.9047 - val_loss: 0.5836 - learning_rate: 1.0000e-05
# Epoch 90/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 474ms/step - accuracy: 0.8778 - loss: 0.6309 - val_accuracy: 0.9047 - val_loss: 0.5841 - learning_rate: 1.0000e-05
# Epoch 91/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 467ms/step - accuracy: 0.8745 - loss: 0.6338 - val_accuracy: 0.9064 - val_loss: 0.5796 - learning_rate: 1.0000e-05
# Epoch 92/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 444ms/step - accuracy: 0.8698 - loss: 0.6323 - val_accuracy: 0.9064 - val_loss: 0.5830 - learning_rate: 1.0000e-05
# Epoch 93/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 461ms/step - accuracy: 0.8710 - loss: 0.6293 - val_accuracy: 0.9047 - val_loss: 0.5840 - learning_rate: 1.0000e-05
# Epoch 94/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - accuracy: 0.8792 - loss: 0.6140 - val_accuracy: 0.9013 - val_loss: 0.5849 - learning_rate: 1.0000e-05
# Epoch 95/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 461ms/step - accuracy: 0.8781 - loss: 0.6162 - val_accuracy: 0.9030 - val_loss: 0.5817 - learning_rate: 1.0000e-05
# Epoch 96/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 443ms/step - accuracy: 0.8800 - loss: 0.6225 - val_accuracy: 0.9030 - val_loss: 0.5804 - learning_rate: 1.0000e-05
# Epoch 97/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - accuracy: 0.8769 - loss: 0.6194 - val_accuracy: 0.9097 - val_loss: 0.5702 - learning_rate: 1.0000e-05
# Epoch 98/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 464ms/step - accuracy: 0.8687 - loss: 0.6307 - val_accuracy: 0.9038 - val_loss: 0.5671 - learning_rate: 1.0000e-05
# Epoch 99/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 445ms/step - accuracy: 0.8748 - loss: 0.6297 - val_accuracy: 0.9130 - val_loss: 0.5594 - learning_rate: 1.0000e-05
# Final validation accuracy: 91.72%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
print(model_filename)
# Out:
# NoPainNoTrain91.72.keras

# %%
# Re-load the model after transfer learning
ft_model = tf.keras.models.load_model('NoPainNoTrain91.72.keras')

# Display a summary of the model architecture
# ft_model.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
# tfk.utils.plot_model(ft_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %%
# Set all EfficientNetB0 layers as non-trainable
for layer in ft_model.get_layer('efficientnetv2-b3').layers:
    layer.trainable = False

# Enable training only for Conv2D and DepthwiseConv2D layers
for i, layer in enumerate(ft_model.get_layer('efficientnetv2-b3').layers):
    if isinstance(layer, tf.keras.layers.Conv2D) or isinstance(layer, tf.keras.layers.DepthwiseConv2D):
        layer.trainable = True
        print(i, layer.name, type(layer).__name__, layer.trainable)
# Out:
# 3 stem_conv Conv2D True
# 6 block1a_project_conv Conv2D True
# 9 block1b_project_conv Conv2D True
# 14 block2a_expand_conv Conv2D True
# 17 block2a_project_conv Conv2D True
# 19 block2b_expand_conv Conv2D True
# 22 block2b_project_conv Conv2D True
# 26 block2c_expand_conv Conv2D True
# 29 block2c_project_conv Conv2D True
# 33 block3a_expand_conv Conv2D True
# 36 block3a_project_conv Conv2D True
# 38 block3b_expand_conv Conv2D True
# 41 block3b_project_conv Conv2D True
# 45 block3c_expand_conv Conv2D True
# 48 block3c_project_conv Conv2D True
# 52 block4a_expand_conv Conv2D True
# 55 block4a_dwconv2 DepthwiseConv2D True
# 60 block4a_se_reduce Conv2D True
# 61 block4a_se_expand Conv2D True
# 63 block4a_project_conv Conv2D True
# 65 block4b_expand_conv Conv2D True
# 68 block4b_dwconv2 DepthwiseConv2D True
# 73 block4b_se_reduce Conv2D True
# 74 block4b_se_expand Conv2D True
# 76 block4b_project_conv Conv2D True
# 80 block4c_expand_conv Conv2D True
# 83 block4c_dwconv2 DepthwiseConv2D True
# 88 block4c_se_reduce Conv2D True
# 89 block4c_se_expand Conv2D True
# 91 block4c_project_conv Conv2D True
# 95 block4d_expand_conv Conv2D True
# 98 block4d_dwconv2 DepthwiseConv2D True
# 103 block4d_se_reduce Conv2D True
# 104 block4d_se_expand Conv2D True
# 106 block4d_project_conv Conv2D True
# 110 block4e_expand_conv Conv2D True
# 113 block4e_dwconv2 DepthwiseConv2D True
# 118 block4e_se_reduce Conv2D True
# 119 block4e_se_expand Conv2D True
# 121 block4e_project_conv Conv2D True
# 125 block5a_expand_conv Conv2D True
# 128 block5a_dwconv2 DepthwiseConv2D True
# 133 block5a_se_reduce Conv2D True
# 134 block5a_se_expand Conv2D True
# 136 block5a_project_conv Conv2D True
# 138 block5b_expand_conv Conv2D True
# 141 block5b_dwconv2 DepthwiseConv2D True
# 146 block5b_se_reduce Conv2D True
# 147 block5b_se_expand Conv2D True
# 149 block5b_project_conv Conv2D True
# 153 block5c_expand_conv Conv2D True
# 156 block5c_dwconv2 DepthwiseConv2D True
# 161 block5c_se_reduce Conv2D True
# 162 block5c_se_expand Conv2D True
# 164 block5c_project_conv Conv2D True
# 168 block5d_expand_conv Conv2D True
# 171 block5d_dwconv2 DepthwiseConv2D True
# 176 block5d_se_reduce Conv2D True
# 177 block5d_se_expand Conv2D True
# 179 block5d_project_conv Conv2D True
# 183 block5e_expand_conv Conv2D True
# 186 block5e_dwconv2 DepthwiseConv2D True
# 191 block5e_se_reduce Conv2D True
# 192 block5e_se_expand Conv2D True
# 194 block5e_project_conv Conv2D True
# 198 block5f_expand_conv Conv2D True
# 201 block5f_dwconv2 DepthwiseConv2D True
# 206 block5f_se_reduce Conv2D True
# 207 block5f_se_expand Conv2D True
# 209 block5f_project_conv Conv2D True
# 213 block5g_expand_conv Conv2D True
# 216 block5g_dwconv2 DepthwiseConv2D True
# 221 block5g_se_reduce Conv2D True
# 222 block5g_se_expand Conv2D True
# 224 block5g_project_conv Conv2D True
# 228 block6a_expand_conv Conv2D True
# 231 block6a_dwconv2 DepthwiseConv2D True
# 236 block6a_se_reduce Conv2D True
# 237 block6a_se_expand Conv2D True
# 239 block6a_project_conv Conv2D True
# 241 block6b_expand_conv Conv2D True
# 244 block6b_dwconv2 DepthwiseConv2D True
# 249 block6b_se_reduce Conv2D True
# 250 block6b_se_expand Conv2D True
# 252 block6b_project_conv Conv2D True
# 256 block6c_expand_conv Conv2D True
# 259 block6c_dwconv2 DepthwiseConv2D True
# 264 block6c_se_reduce Conv2D True
# 265 block6c_se_expand Conv2D True
# 267 block6c_project_conv Conv2D True
# 271 block6d_expand_conv Conv2D True
# 274 block6d_dwconv2 DepthwiseConv2D True
# 279 block6d_se_reduce Conv2D True
# 280 block6d_se_expand Conv2D True
# 282 block6d_project_conv Conv2D True
# 286 block6e_expand_conv Conv2D True
# 289 block6e_dwconv2 DepthwiseConv2D True
# 294 block6e_se_reduce Conv2D True
# 295 block6e_se_expand Conv2D True
# 297 block6e_project_conv Conv2D True
# 301 block6f_expand_conv Conv2D True
# 304 block6f_dwconv2 DepthwiseConv2D True
# 309 block6f_se_reduce Conv2D True
# 310 block6f_se_expand Conv2D True
# 312 block6f_project_conv Conv2D True
# 316 block6g_expand_conv Conv2D True
# 319 block6g_dwconv2 DepthwiseConv2D True
# 324 block6g_se_reduce Conv2D True
# 325 block6g_se_expand Conv2D True
# 327 block6g_project_conv Conv2D True
# 331 block6h_expand_conv Conv2D True
# 334 block6h_dwconv2 DepthwiseConv2D True
# 339 block6h_se_reduce Conv2D True
# 340 block6h_se_expand Conv2D True
# 342 block6h_project_conv Conv2D True
# 346 block6i_expand_conv Conv2D True
# 349 block6i_dwconv2 DepthwiseConv2D True
# 354 block6i_se_reduce Conv2D True
# 355 block6i_se_expand Conv2D True
# 357 block6i_project_conv Conv2D True
# 361 block6j_expand_conv Conv2D True
# 364 block6j_dwconv2 DepthwiseConv2D True
# 369 block6j_se_reduce Conv2D True
# 370 block6j_se_expand Conv2D True
# 372 block6j_project_conv Conv2D True
# 376 block6k_expand_conv Conv2D True
# 379 block6k_dwconv2 DepthwiseConv2D True
# 384 block6k_se_reduce Conv2D True
# 385 block6k_se_expand Conv2D True
# 387 block6k_project_conv Conv2D True
# 391 block6l_expand_conv Conv2D True
# 394 block6l_dwconv2 DepthwiseConv2D True
# 399 block6l_se_reduce Conv2D True
# 400 block6l_se_expand Conv2D True
# 402 block6l_project_conv Conv2D True
# 406 top_conv Conv2D True

# %%
# Set the number of layers to freeze

# Calcola i parametri totali
trainable_params = sum(
    tf.reduce_sum([tf.size(var) for var in layer.trainable_weights]).numpy()
    for layer in ft_model.get_layer('efficientnetv2-b3').layers
)
target_params = 0.9 * trainable_params  # Il 10% dei parametri totali

# Trova N
cumulative_params = 0
N = 0
for i, layer in enumerate(ft_model.get_layer('efficientnetv2-b3').layers):
    cumulative_params += sum(tf.size(var).numpy() for var in layer.trainable_weights)
    if cumulative_params >= target_params:
        N = i
        break

print(N)

# Set the first N layers as non-trainable
for i, layer in enumerate(ft_model.get_layer('efficientnetv2-b3').layers[:N]):
    layer.trainable = False

# Print layer indices, names, and trainability status
for i, layer in enumerate(ft_model.get_layer('efficientnetv2-b3').layers):
    print(i, layer.name, layer.trainable)

# Display a summary of the model architecture
 #ft_model.summary(expand_nested=False, show_trainable=True)


# Display model architecture with layer shapes and trainable parameters
# tfk.utils.plot_model(ft_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# 387
# 0 input_layer False
# 1 rescaling False
# 2 normalization False
# 3 stem_conv False
# 4 stem_bn False
# 5 stem_activation False
# 6 block1a_project_conv False
# 7 block1a_project_bn False
# 8 block1a_project_activation False
# 9 block1b_project_conv False
# 10 block1b_project_bn False
# 11 block1b_project_activation False
# 12 block1b_drop False
# 13 block1b_add False
# 14 block2a_expand_conv False
# 15 block2a_expand_bn False
# 16 block2a_expand_activation False
# 17 block2a_project_conv False
# 18 block2a_project_bn False
# 19 block2b_expand_conv False
# 20 block2b_expand_bn False
# 21 block2b_expand_activation False
# 22 block2b_project_conv False
# 23 block2b_project_bn False
# 24 block2b_drop False
# 25 block2b_add False
# 26 block2c_expand_conv False
# 27 block2c_expand_bn False
# 28 block2c_expand_activation False
# 29 block2c_project_conv False
# 30 block2c_project_bn False
# 31 block2c_drop False
# 32 block2c_add False
# 33 block3a_expand_conv False
# 34 block3a_expand_bn False
# 35 block3a_expand_activation False
# 36 block3a_project_conv False
# 37 block3a_project_bn False
# 38 block3b_expand_conv False
# 39 block3b_expand_bn False
# 40 block3b_expand_activation False
# 41 block3b_project_conv False
# 42 block3b_project_bn False
# 43 block3b_drop False
# 44 block3b_add False
# 45 block3c_expand_conv False
# 46 block3c_expand_bn False
# 47 block3c_expand_activation False
# 48 block3c_project_conv False
# 49 block3c_project_bn False
# 50 block3c_drop False
# 51 block3c_add False
# 52 block4a_expand_conv False
# 53 block4a_expand_bn False
# 54 block4a_expand_activation False
# 55 block4a_dwconv2 False
# 56 block4a_bn False
# 57 block4a_activation False
# 58 block4a_se_squeeze False
# 59 block4a_se_reshape False
# 60 block4a_se_reduce False
# 61 block4a_se_expand False
# 62 block4a_se_excite False
# 63 block4a_project_conv False
# 64 block4a_project_bn False
# 65 block4b_expand_conv False
# 66 block4b_expand_bn False
# 67 block4b_expand_activation False
# 68 block4b_dwconv2 False
# 69 block4b_bn False
# 70 block4b_activation False
# 71 block4b_se_squeeze False
# 72 block4b_se_reshape False
# 73 block4b_se_reduce False
# 74 block4b_se_expand False
# 75 block4b_se_excite False
# 76 block4b_project_conv False
# 77 block4b_project_bn False
# 78 block4b_drop False
# 79 block4b_add False
# 80 block4c_expand_conv False
# 81 block4c_expand_bn False
# 82 block4c_expand_activation False
# 83 block4c_dwconv2 False
# 84 block4c_bn False
# 85 block4c_activation False
# 86 block4c_se_squeeze False
# 87 block4c_se_reshape False
# 88 block4c_se_reduce False
# 89 block4c_se_expand False
# 90 block4c_se_excite False
# 91 block4c_project_conv False
# 92 block4c_project_bn False
# 93 block4c_drop False
# 94 block4c_add False
# 95 block4d_expand_conv False
# 96 block4d_expand_bn False
# 97 block4d_expand_activation False
# 98 block4d_dwconv2 False
# 99 block4d_bn False
# 100 block4d_activation False
# 101 block4d_se_squeeze False
# 102 block4d_se_reshape False
# 103 block4d_se_reduce False
# 104 block4d_se_expand False
# 105 block4d_se_excite False
# 106 block4d_project_conv False
# 107 block4d_project_bn False
# 108 block4d_drop False
# 109 block4d_add False
# 110 block4e_expand_conv False
# 111 block4e_expand_bn False
# 112 block4e_expand_activation False
# 113 block4e_dwconv2 False
# 114 block4e_bn False
# 115 block4e_activation False
# 116 block4e_se_squeeze False
# 117 block4e_se_reshape False
# 118 block4e_se_reduce False
# 119 block4e_se_expand False
# 120 block4e_se_excite False
# 121 block4e_project_conv False
# 122 block4e_project_bn False
# 123 block4e_drop False
# 124 block4e_add False
# 125 block5a_expand_conv False
# 126 block5a_expand_bn False
# 127 block5a_expand_activation False
# 128 block5a_dwconv2 False
# 129 block5a_bn False
# 130 block5a_activation False
# 131 block5a_se_squeeze False
# 132 block5a_se_reshape False
# 133 block5a_se_reduce False
# 134 block5a_se_expand False
# 135 block5a_se_excite False
# 136 block5a_project_conv False
# 137 block5a_project_bn False
# 138 block5b_expand_conv False
# 139 block5b_expand_bn False
# 140 block5b_expand_activation False
# 141 block5b_dwconv2 False
# 142 block5b_bn False
# 143 block5b_activation False
# 144 block5b_se_squeeze False
# 145 block5b_se_reshape False
# 146 block5b_se_reduce False
# 147 block5b_se_expand False
# 148 block5b_se_excite False
# 149 block5b_project_conv False
# 150 block5b_project_bn False
# 151 block5b_drop False
# 152 block5b_add False
# 153 block5c_expand_conv False
# 154 block5c_expand_bn False
# 155 block5c_expand_activation False
# 156 block5c_dwconv2 False
# 157 block5c_bn False
# 158 block5c_activation False
# 159 block5c_se_squeeze False
# 160 block5c_se_reshape False
# 161 block5c_se_reduce False
# 162 block5c_se_expand False
# 163 block5c_se_excite False
# 164 block5c_project_conv False
# 165 block5c_project_bn False
# 166 block5c_drop False
# 167 block5c_add False
# 168 block5d_expand_conv False
# 169 block5d_expand_bn False
# 170 block5d_expand_activation False
# 171 block5d_dwconv2 False
# 172 block5d_bn False
# 173 block5d_activation False
# 174 block5d_se_squeeze False
# 175 block5d_se_reshape False
# 176 block5d_se_reduce False
# 177 block5d_se_expand False
# 178 block5d_se_excite False
# 179 block5d_project_conv False
# 180 block5d_project_bn False
# 181 block5d_drop False
# 182 block5d_add False
# 183 block5e_expand_conv False
# 184 block5e_expand_bn False
# 185 block5e_expand_activation False
# 186 block5e_dwconv2 False
# 187 block5e_bn False
# 188 block5e_activation False
# 189 block5e_se_squeeze False
# 190 block5e_se_reshape False
# 191 block5e_se_reduce False
# 192 block5e_se_expand False
# 193 block5e_se_excite False
# 194 block5e_project_conv False
# 195 block5e_project_bn False
# 196 block5e_drop False
# 197 block5e_add False
# 198 block5f_expand_conv False
# 199 block5f_expand_bn False
# 200 block5f_expand_activation False
# 201 block5f_dwconv2 False
# 202 block5f_bn False
# 203 block5f_activation False
# 204 block5f_se_squeeze False
# 205 block5f_se_reshape False
# 206 block5f_se_reduce False
# 207 block5f_se_expand False
# 208 block5f_se_excite False
# 209 block5f_project_conv False
# 210 block5f_project_bn False
# 211 block5f_drop False
# 212 block5f_add False
# 213 block5g_expand_conv False
# 214 block5g_expand_bn False
# 215 block5g_expand_activation False
# 216 block5g_dwconv2 False
# 217 block5g_bn False
# 218 block5g_activation False
# 219 block5g_se_squeeze False
# 220 block5g_se_reshape False
# 221 block5g_se_reduce False
# 222 block5g_se_expand False
# 223 block5g_se_excite False
# 224 block5g_project_conv False
# 225 block5g_project_bn False
# 226 block5g_drop False
# 227 block5g_add False
# 228 block6a_expand_conv False
# 229 block6a_expand_bn False
# 230 block6a_expand_activation False
# 231 block6a_dwconv2 False
# 232 block6a_bn False
# 233 block6a_activation False
# 234 block6a_se_squeeze False
# 235 block6a_se_reshape False
# 236 block6a_se_reduce False
# 237 block6a_se_expand False
# 238 block6a_se_excite False
# 239 block6a_project_conv False
# 240 block6a_project_bn False
# 241 block6b_expand_conv False
# 242 block6b_expand_bn False
# 243 block6b_expand_activation False
# 244 block6b_dwconv2 False
# 245 block6b_bn False
# 246 block6b_activation False
# 247 block6b_se_squeeze False
# 248 block6b_se_reshape False
# 249 block6b_se_reduce False
# 250 block6b_se_expand False
# 251 block6b_se_excite False
# 252 block6b_project_conv False
# 253 block6b_project_bn False
# 254 block6b_drop False
# 255 block6b_add False
# 256 block6c_expand_conv False
# 257 block6c_expand_bn False
# 258 block6c_expand_activation False
# 259 block6c_dwconv2 False
# 260 block6c_bn False
# 261 block6c_activation False
# 262 block6c_se_squeeze False
# 263 block6c_se_reshape False
# 264 block6c_se_reduce False
# 265 block6c_se_expand False
# 266 block6c_se_excite False
# 267 block6c_project_conv False
# 268 block6c_project_bn False
# 269 block6c_drop False
# 270 block6c_add False
# 271 block6d_expand_conv False
# 272 block6d_expand_bn False
# 273 block6d_expand_activation False
# 274 block6d_dwconv2 False
# 275 block6d_bn False
# 276 block6d_activation False
# 277 block6d_se_squeeze False
# 278 block6d_se_reshape False
# 279 block6d_se_reduce False
# 280 block6d_se_expand False
# 281 block6d_se_excite False
# 282 block6d_project_conv False
# 283 block6d_project_bn False
# 284 block6d_drop False
# 285 block6d_add False
# 286 block6e_expand_conv False
# 287 block6e_expand_bn False
# 288 block6e_expand_activation False
# 289 block6e_dwconv2 False
# 290 block6e_bn False
# 291 block6e_activation False
# 292 block6e_se_squeeze False
# 293 block6e_se_reshape False
# 294 block6e_se_reduce False
# 295 block6e_se_expand False
# 296 block6e_se_excite False
# 297 block6e_project_conv False
# 298 block6e_project_bn False
# 299 block6e_drop False
# 300 block6e_add False
# 301 block6f_expand_conv False
# 302 block6f_expand_bn False
# 303 block6f_expand_activation False
# 304 block6f_dwconv2 False
# 305 block6f_bn False
# 306 block6f_activation False
# 307 block6f_se_squeeze False
# 308 block6f_se_reshape False
# 309 block6f_se_reduce False
# 310 block6f_se_expand False
# 311 block6f_se_excite False
# 312 block6f_project_conv False
# 313 block6f_project_bn False
# 314 block6f_drop False
# 315 block6f_add False
# 316 block6g_expand_conv False
# 317 block6g_expand_bn False
# 318 block6g_expand_activation False
# 319 block6g_dwconv2 False
# 320 block6g_bn False
# 321 block6g_activation False
# 322 block6g_se_squeeze False
# 323 block6g_se_reshape False
# 324 block6g_se_reduce False
# 325 block6g_se_expand False
# 326 block6g_se_excite False
# 327 block6g_project_conv False
# 328 block6g_project_bn False
# 329 block6g_drop False
# 330 block6g_add False
# 331 block6h_expand_conv False
# 332 block6h_expand_bn False
# 333 block6h_expand_activation False
# 334 block6h_dwconv2 False
# 335 block6h_bn False
# 336 block6h_activation False
# 337 block6h_se_squeeze False
# 338 block6h_se_reshape False
# 339 block6h_se_reduce False
# 340 block6h_se_expand False
# 341 block6h_se_excite False
# 342 block6h_project_conv False
# 343 block6h_project_bn False
# 344 block6h_drop False
# 345 block6h_add False
# 346 block6i_expand_conv False
# 347 block6i_expand_bn False
# 348 block6i_expand_activation False
# 349 block6i_dwconv2 False
# 350 block6i_bn False
# 351 block6i_activation False
# 352 block6i_se_squeeze False
# 353 block6i_se_reshape False
# 354 block6i_se_reduce False
# 355 block6i_se_expand False
# 356 block6i_se_excite False
# 357 block6i_project_conv False
# 358 block6i_project_bn False
# 359 block6i_drop False
# 360 block6i_add False
# 361 block6j_expand_conv False
# 362 block6j_expand_bn False
# 363 block6j_expand_activation False
# 364 block6j_dwconv2 False
# 365 block6j_bn False
# 366 block6j_activation False
# 367 block6j_se_squeeze False
# 368 block6j_se_reshape False
# 369 block6j_se_reduce False
# 370 block6j_se_expand False
# 371 block6j_se_excite False
# 372 block6j_project_conv False
# 373 block6j_project_bn False
# 374 block6j_drop False
# 375 block6j_add False
# 376 block6k_expand_conv False
# 377 block6k_expand_bn False
# 378 block6k_expand_activation False
# 379 block6k_dwconv2 False
# 380 block6k_bn False
# 381 block6k_activation False
# 382 block6k_se_squeeze False
# 383 block6k_se_reshape False
# 384 block6k_se_reduce False
# 385 block6k_se_expand False
# 386 block6k_se_excite False
# 387 block6k_project_conv True
# 388 block6k_project_bn False
# 389 block6k_drop False
# 390 block6k_add False
# 391 block6l_expand_conv True
# 392 block6l_expand_bn False
# 393 block6l_expand_activation False
# 394 block6l_dwconv2 True
# 395 block6l_bn False
# 396 block6l_activation False
# 397 block6l_se_squeeze False
# 398 block6l_se_reshape False
# 399 block6l_se_reduce True
# 400 block6l_se_expand True
# 401 block6l_se_excite False
# 402 block6l_project_conv True
# 403 block6l_project_bn False
# 404 block6l_drop False
# 405 block6l_add False
# 406 top_conv True
# 407 top_bn False
# 408 top_activation False
# 409 max_pool False

# %%
# Compile the model
loss = losses.CategoricalCrossentropy()
optimizer = tf.keras.optimizers.Lion(learning_rate = 1e-4)
metrics = ['accuracy']
ft_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Fine-tune the model
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Metric to monitor
    factor=0.1,          # Factor to reduce learning rate by (0.1 means divide by 10)
    patience=5,          # Number of epochs to wait before reducing
    min_lr=5e-6       # Minimum learning rate
)

# Create an EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=15,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [reduce_lr,early_stopping]

ft_history = ft_model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    callbacks = callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'NoPainNoTrainFT'+str(final_val_accuracy)+'.keras'
ft_model.save(model_filename)

# Delete the model to free up resources
del ft_model
# Out:
# Epoch 1/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 932ms/step - accuracy: 0.8730 - loss: 0.6498 - val_accuracy: 0.8930 - val_loss: 0.6125 - learning_rate: 1.0000e-04
# Epoch 2/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 459ms/step - accuracy: 0.8840 - loss: 0.6157 - val_accuracy: 0.8880 - val_loss: 0.5852 - learning_rate: 1.0000e-04
# Epoch 3/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 490ms/step - accuracy: 0.8896 - loss: 0.6020 - val_accuracy: 0.9022 - val_loss: 0.5608 - learning_rate: 1.0000e-04
# Epoch 4/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 502ms/step - accuracy: 0.8923 - loss: 0.5778 - val_accuracy: 0.9164 - val_loss: 0.5219 - learning_rate: 1.0000e-04
# Epoch 5/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 467ms/step - accuracy: 0.8981 - loss: 0.5611 - val_accuracy: 0.8946 - val_loss: 0.5515 - learning_rate: 1.0000e-04
# Epoch 6/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.9052 - loss: 0.5367 - val_accuracy: 0.9089 - val_loss: 0.5066 - learning_rate: 1.0000e-04
# Epoch 7/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 486ms/step - accuracy: 0.9111 - loss: 0.5244 - val_accuracy: 0.9047 - val_loss: 0.5422 - learning_rate: 1.0000e-04
# Epoch 8/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 482ms/step - accuracy: 0.9115 - loss: 0.5200 - val_accuracy: 0.9189 - val_loss: 0.5026 - learning_rate: 1.0000e-04
# Epoch 9/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 479ms/step - accuracy: 0.9102 - loss: 0.5162 - val_accuracy: 0.9222 - val_loss: 0.4953 - learning_rate: 1.0000e-04
# Epoch 10/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 497ms/step - accuracy: 0.9136 - loss: 0.5020 - val_accuracy: 0.9197 - val_loss: 0.4889 - learning_rate: 1.0000e-04
# Epoch 11/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 482ms/step - accuracy: 0.9153 - loss: 0.4942 - val_accuracy: 0.9256 - val_loss: 0.4735 - learning_rate: 1.0000e-04
# Epoch 12/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - accuracy: 0.9188 - loss: 0.4824 - val_accuracy: 0.9281 - val_loss: 0.4740 - learning_rate: 1.0000e-04
# Epoch 13/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 475ms/step - accuracy: 0.9214 - loss: 0.4806 - val_accuracy: 0.9256 - val_loss: 0.4721 - learning_rate: 1.0000e-04
# Epoch 14/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 476ms/step - accuracy: 0.9180 - loss: 0.4819 - val_accuracy: 0.9348 - val_loss: 0.4330 - learning_rate: 1.0000e-04
# Epoch 15/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 479ms/step - accuracy: 0.9211 - loss: 0.4671 - val_accuracy: 0.9448 - val_loss: 0.4128 - learning_rate: 1.0000e-04
# Epoch 16/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 488ms/step - accuracy: 0.9281 - loss: 0.4533 - val_accuracy: 0.9440 - val_loss: 0.4062 - learning_rate: 1.0000e-04
# Epoch 17/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 464ms/step - accuracy: 0.9161 - loss: 0.4691 - val_accuracy: 0.9431 - val_loss: 0.4123 - learning_rate: 1.0000e-04
# Epoch 18/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 496ms/step - accuracy: 0.9237 - loss: 0.4590 - val_accuracy: 0.9507 - val_loss: 0.4133 - learning_rate: 1.0000e-04
# Epoch 19/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 476ms/step - accuracy: 0.9282 - loss: 0.4518 - val_accuracy: 0.9398 - val_loss: 0.4127 - learning_rate: 1.0000e-04
# Epoch 20/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 476ms/step - accuracy: 0.9272 - loss: 0.4411 - val_accuracy: 0.9381 - val_loss: 0.4148 - learning_rate: 1.0000e-04
# Epoch 21/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 487ms/step - accuracy: 0.9326 - loss: 0.4393 - val_accuracy: 0.9390 - val_loss: 0.3962 - learning_rate: 1.0000e-04
# Epoch 22/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 481ms/step - accuracy: 0.9265 - loss: 0.4400 - val_accuracy: 0.9281 - val_loss: 0.4227 - learning_rate: 1.0000e-04
# Epoch 23/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 474ms/step - accuracy: 0.9271 - loss: 0.4323 - val_accuracy: 0.9406 - val_loss: 0.3859 - learning_rate: 1.0000e-04
# Epoch 24/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 470ms/step - accuracy: 0.9324 - loss: 0.4273 - val_accuracy: 0.9431 - val_loss: 0.3760 - learning_rate: 1.0000e-04
# Epoch 25/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 459ms/step - accuracy: 0.9263 - loss: 0.4344 - val_accuracy: 0.9490 - val_loss: 0.3505 - learning_rate: 1.0000e-04
# Epoch 26/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 482ms/step - accuracy: 0.9354 - loss: 0.4190 - val_accuracy: 0.9440 - val_loss: 0.3704 - learning_rate: 1.0000e-04
# Epoch 27/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 459ms/step - accuracy: 0.9376 - loss: 0.4115 - val_accuracy: 0.9406 - val_loss: 0.3649 - learning_rate: 1.0000e-04
# Epoch 28/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 457ms/step - accuracy: 0.9333 - loss: 0.4167 - val_accuracy: 0.9490 - val_loss: 0.3513 - learning_rate: 1.0000e-04
# Epoch 29/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 458ms/step - accuracy: 0.9317 - loss: 0.4183 - val_accuracy: 0.9498 - val_loss: 0.3497 - learning_rate: 1.0000e-04
# Epoch 30/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 482ms/step - accuracy: 0.9344 - loss: 0.4099 - val_accuracy: 0.9440 - val_loss: 0.3567 - learning_rate: 1.0000e-04
# Epoch 31/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 485ms/step - accuracy: 0.9372 - loss: 0.4050 - val_accuracy: 0.9440 - val_loss: 0.3671 - learning_rate: 1.0000e-04
# Epoch 32/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - accuracy: 0.9333 - loss: 0.4110 - val_accuracy: 0.9574 - val_loss: 0.3409 - learning_rate: 1.0000e-04
# Epoch 33/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 477ms/step - accuracy: 0.9357 - loss: 0.4004 - val_accuracy: 0.9540 - val_loss: 0.3446 - learning_rate: 1.0000e-04
# Epoch 34/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 477ms/step - accuracy: 0.9341 - loss: 0.4047 - val_accuracy: 0.9540 - val_loss: 0.3387 - learning_rate: 1.0000e-04
# Epoch 35/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 466ms/step - accuracy: 0.9369 - loss: 0.3982 - val_accuracy: 0.9473 - val_loss: 0.3581 - learning_rate: 1.0000e-04
# Epoch 36/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.9340 - loss: 0.3934 - val_accuracy: 0.9557 - val_loss: 0.3299 - learning_rate: 1.0000e-04
# Epoch 37/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 476ms/step - accuracy: 0.9370 - loss: 0.3938 - val_accuracy: 0.9498 - val_loss: 0.3502 - learning_rate: 1.0000e-04
# Epoch 38/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 476ms/step - accuracy: 0.9388 - loss: 0.3862 - val_accuracy: 0.9473 - val_loss: 0.3571 - learning_rate: 1.0000e-04
# Epoch 39/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 485ms/step - accuracy: 0.9404 - loss: 0.3822 - val_accuracy: 0.9523 - val_loss: 0.3387 - learning_rate: 1.0000e-04
# Epoch 40/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 485ms/step - accuracy: 0.9383 - loss: 0.3850 - val_accuracy: 0.9532 - val_loss: 0.3407 - learning_rate: 1.0000e-04
# Epoch 41/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 495ms/step - accuracy: 0.9371 - loss: 0.3859 - val_accuracy: 0.9582 - val_loss: 0.3184 - learning_rate: 1.0000e-04
# Epoch 42/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.9416 - loss: 0.3738 - val_accuracy: 0.9540 - val_loss: 0.3350 - learning_rate: 1.0000e-04
# Epoch 43/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.9388 - loss: 0.3759 - val_accuracy: 0.9540 - val_loss: 0.3265 - learning_rate: 1.0000e-04
# Epoch 44/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 466ms/step - accuracy: 0.9365 - loss: 0.3820 - val_accuracy: 0.9557 - val_loss: 0.3157 - learning_rate: 1.0000e-04
# Epoch 45/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 482ms/step - accuracy: 0.9426 - loss: 0.3717 - val_accuracy: 0.9565 - val_loss: 0.3208 - learning_rate: 1.0000e-04
# Epoch 46/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 476ms/step - accuracy: 0.9401 - loss: 0.3725 - val_accuracy: 0.9532 - val_loss: 0.3199 - learning_rate: 1.0000e-04
# Epoch 47/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 489ms/step - accuracy: 0.9393 - loss: 0.3743 - val_accuracy: 0.9565 - val_loss: 0.3237 - learning_rate: 1.0000e-04
# Epoch 48/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 470ms/step - accuracy: 0.9415 - loss: 0.3731 - val_accuracy: 0.9548 - val_loss: 0.3157 - learning_rate: 1.0000e-04
# Epoch 49/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 475ms/step - accuracy: 0.9407 - loss: 0.3649 - val_accuracy: 0.9548 - val_loss: 0.3220 - learning_rate: 1.0000e-04
# Epoch 50/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 457ms/step - accuracy: 0.9438 - loss: 0.3662 - val_accuracy: 0.9523 - val_loss: 0.3188 - learning_rate: 1.0000e-05
# Epoch 51/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 484ms/step - accuracy: 0.9451 - loss: 0.3566 - val_accuracy: 0.9457 - val_loss: 0.3291 - learning_rate: 1.0000e-05
# Epoch 52/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.9456 - loss: 0.3605 - val_accuracy: 0.9440 - val_loss: 0.3346 - learning_rate: 1.0000e-05
# Epoch 53/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.9431 - loss: 0.3607 - val_accuracy: 0.9431 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 54/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 458ms/step - accuracy: 0.9512 - loss: 0.3483 - val_accuracy: 0.9473 - val_loss: 0.3263 - learning_rate: 1.0000e-05
# Epoch 55/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.9464 - loss: 0.3556 - val_accuracy: 0.9498 - val_loss: 0.3255 - learning_rate: 5.0000e-06
# Epoch 56/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 462ms/step - accuracy: 0.9458 - loss: 0.3527 - val_accuracy: 0.9490 - val_loss: 0.3271 - learning_rate: 5.0000e-06
# Final validation accuracy: 95.82%

# %%
print(model_filename)
# Out:
# NoPainNoTrainFT95.82.keras

# %%
# Load the saved model
model = tf.keras.models.load_model('NoPainNoTrainFT95.82.keras')

# %% [markdown]
# ## 📊 Prepare Your Submission
#
# To prepare your submission, create a `.zip` file that includes all the necessary code to run your model. It **must** include a `model.py` file with the following class:
#
# ```python
# # file: model.py
# class Model:
#     def __init__(self):
#         """Initialize the internal state of the model."""
#
#     def predict(self, X):
#         """Return a numpy array with the labels corresponding to the input X."""
# ```
#
# The next cell shows an example implementation of the `model.py` file, which includes loading model weights from the `weights.keras` file and conducting predictions on provided input data. The `.zip` file is created and downloaded in the last notebook cell.
#
# ❗ Feel free to modify the method implementations to better fit your specific requirements, but please ensure that the class name and method interfaces remain unchanged.

# %%
# %%writefile model.py
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.

        The following is an example loading the weights of a pre-trained
        model.
        """
        self.neural_network = tfk.models.load_model('NoPainNoTrainFT95.82.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must no be one-hot
        encoded.

        The following is an example of a prediction from the pre-trained model
        loaded in the __init__ method.
        """
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Writing model.py

# %%
from datetime import datetime
filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py NoPainNoTrainFT95.82.keras

from google.colab import files
files.download(filename)
# Out:
#   adding: model.py (deflated 55%)
#   adding: NoPainNoTrainFT95.82.keras (deflated 9%)
