# %% [markdown]
# # ConvNeXtSmall

# %% [markdown]
# ## 🌐 Connect Colab to Google Drive

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/MyDrive/AN2DL
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/AN2DL

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Set the global policy for mixed precision (16/32-bit float)
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
from PIL import Image
import matplotlib.gridspec as gridspec

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data
data = np.load('filtered_data.npz')
X = data['images']
y = data['labels']

# %%
# Display a sample of images from the training-validation dataset
num_img = 10
random.seed(10)
random_indices = random.sample(range(len(X)), num_img)

fig, axes = plt.subplots(1, num_img, figsize=(20, 20))

# Iterate through the selected number of images
for i, idx in enumerate(random_indices):
    ax = axes[i % num_img]
    ax.imshow(np.squeeze(X[idx]), vmin=0., vmax=1.)
    ax.set_title(f'{y[idx]}')
    ax.axis('off')

# Adjust layout and display the images
plt.tight_layout()
plt.show()

# %%
# Inspect the target
print('Counting occurrences of target classes:')
print(pd.DataFrame(y, columns=['digit'])['digit'].value_counts())
# Out:
# Counting occurrences of target classes:
# digit
# 6    2330
# 1    2181
# 3    2026
# 7    1643
# 2    1085
# 5     993
# 0     852
# 4     849
# Name: count, dtype: int64

# %%
# WITHOUT A TEST SET

# Convert labels to categorical format using one-hot encoding
y = tfk.utils.to_categorical(y)

from tensorflow.keras.utils import to_categorical

# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=seed, test_size=0.1, stratify=y)

# Numero di classi nel dataset
num_classes = len(np.unique(y))  # Ad esempio, 8 classi

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (10763, 96, 96, 3)
# Training Label Shape: (10763, 8)
# Validation Data Shape: (1196, 96, 96, 3)
# Validation Label Shape: (1196, 8)

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8

# %%
# Number of training epochs
epochs = 500

# Batch size for training
batch_size = 1024

# Learning rate: step size for updating the model's weights
learning_rate = 5e-4

# Print the defined parameters
print("Epochs:", epochs)
print("Batch Size:", batch_size)
print("Learning Rare:", learning_rate)
# Out:
# Epochs: 500
# Batch Size: 1024
# Learning Rare: 0.0005

# %%
# Initialise MobileNetV3Small model with pretrained weights, for transfer learning
net = tfk.applications.ConvNeXtSmall(
    include_top=False,
    include_preprocessing=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=input_shape,
    pooling='max',
    name="convnext_small",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_small_notop.h5
# 198551472/198551472 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Freeze all layers in EfficientNetB0 to use it solely as a feature extractor
net.trainable = False

# Apply data augmentation for training robustness
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(1),
    tfkl.RandomZoom(0.05),
    tfkl.RandomContrast(0.25),
], name='preprocessing')

# %%
import tensorflow as tf
from tensorflow.keras import layers as tfkl, models as tfk, losses, optimizers, initializers, regularizers
from tensorflow.keras.layers import Resizing

def build_model(
    input_shape,
    output_shape,
    learning_rate,
    seed,
    augmentation=None, # Add augmentation as an optional parameter
    l2_lambda=5e-2
):
    tf.random.set_seed(seed)

    # Define the input layer
    inputs = tfkl.Input(shape=input_shape, name='Input')

    # Apply augmentation if provided (use a dictionary format for MixUp)
    if augmentation:
        x = augmentation(inputs)
    else:
        x = inputs

    # Weight initialization and regularization
    initializer = initializers.HeNormal(seed=seed)
    regularizer = regularizers.l2(l2_lambda)

    # Pass augmented inputs through the network feature extractor
    x = net(x)

    # Fully Connected Layers
    x = tfkl.Dense(64, kernel_initializer=initializer, kernel_regularizer=regularizer)(x)
    x = tfkl.BatchNormalization(beta_regularizer=regularizer)(x)
    x = tfkl.Activation('relu')(x)

    # Output Layer
    outputs = tfkl.Dense(output_shape, kernel_initializer=initializer, kernel_regularizer=regularizer, activation='softmax', dtype='float32', name='output')(x)

    model = tfk.Model(inputs=inputs, outputs=outputs, name='CNN')

    # Corrected loss and optimizer imports
    loss = losses.CategoricalCrossentropy()
    optimizer = tf.keras.optimizers.Lion(learning_rate = 5e-4)
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    return model

# %%
from sklearn.utils import class_weight
import numpy as np

# If y_train is one-hot encoded, convert it to integer labels
if len(y_train.shape) > 1:
  y_train_int = np.argmax(y_train, axis=1)  # Converts one-hot to integer labels


# Compute class weights
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train_int),
    y=y_train_int
)

# Convert the result into a dictionary
class_weight_dict = dict(enumerate(class_weights))

# %%
# Build the model with specified input and output shapes
model = build_model(input_shape=input_shape, output_shape=output_shape, learning_rate=learning_rate, seed=seed, augmentation=augmentation)

# Display a summary of the model architecture
model.summary(expand_nested=False, show_trainable=True)

# Plot the model architecture with the correct import
# plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ cast_4 (Cast)                       │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ preprocessing (Sequential)          │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ convnext_small (Functional)         │ (None, 768)                  │    49,454,688 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 64)                   │        49,216 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ batch_normalization                 │ (None, 64)                   │           256 │    Y    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation (Activation)             │ (None, 64)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ cast_5 (Cast)                       │ (None, 64)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ output (Dense)                      │ (None, 8)                    │           520 │    Y    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 49,504,680 (188.85 MB)
#  Trainable params: 49,864 (194.78 KB)
#  Non-trainable params: 49,454,816 (188.66 MB)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping  # Import EarlyStopping directly
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define the patience value for early stopping
patience = 30

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Metric to monitor
    factor=0.2,          # Factor to reduce learning rate by (0.1 means divide by 10)
    patience=5,          # Number of epochs to wait before reducing
    min_lr=1e-5       # Minimum learning rate
)

# Create an EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [reduce_lr,early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks,
    class_weight=class_weight_dict,
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'NoPainNoTrain'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.1712 - loss: 9.3056 - val_accuracy: 0.3010 - val_loss: 8.2195 - learning_rate: 5.0000e-04
# Epoch 2/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.3422 - loss: 7.9306 - val_accuracy: 0.4164 - val_loss: 7.1806 - learning_rate: 5.0000e-04
# Epoch 3/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.4656 - loss: 6.8275 - val_accuracy: 0.4640 - val_loss: 6.2941 - learning_rate: 5.0000e-04
# Epoch 4/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.5365 - loss: 5.9147 - val_accuracy: 0.4975 - val_loss: 5.5054 - learning_rate: 5.0000e-04
# Epoch 5/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.5840 - loss: 5.1255 - val_accuracy: 0.5167 - val_loss: 4.8098 - learning_rate: 5.0000e-04
# Epoch 6/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.6179 - loss: 4.4432 - val_accuracy: 0.5368 - val_loss: 4.2088 - learning_rate: 5.0000e-04
# Epoch 7/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.6513 - loss: 3.8635 - val_accuracy: 0.5510 - val_loss: 3.7077 - learning_rate: 5.0000e-04
# Epoch 8/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.6810 - loss: 3.3749 - val_accuracy: 0.5694 - val_loss: 3.3175 - learning_rate: 5.0000e-04
# Epoch 9/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.7008 - loss: 2.9854 - val_accuracy: 0.6221 - val_loss: 2.9596 - learning_rate: 5.0000e-04
# Epoch 10/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.7243 - loss: 2.6373 - val_accuracy: 0.6530 - val_loss: 2.6871 - learning_rate: 5.0000e-04
# Epoch 11/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.7481 - loss: 2.3598 - val_accuracy: 0.6764 - val_loss: 2.5140 - learning_rate: 5.0000e-04
# Epoch 12/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.7489 - loss: 2.1558 - val_accuracy: 0.7057 - val_loss: 2.3816 - learning_rate: 5.0000e-04
# Epoch 13/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.7767 - loss: 1.9578 - val_accuracy: 0.7458 - val_loss: 2.2532 - learning_rate: 5.0000e-04
# Epoch 14/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.7839 - loss: 1.8236 - val_accuracy: 0.7709 - val_loss: 2.1817 - learning_rate: 5.0000e-04
# Epoch 15/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.7818 - loss: 1.7347 - val_accuracy: 0.8069 - val_loss: 2.1124 - learning_rate: 5.0000e-04
# Epoch 16/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8088 - loss: 1.6196 - val_accuracy: 0.8119 - val_loss: 2.0800 - learning_rate: 5.0000e-04
# Epoch 17/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8142 - loss: 1.5583 - val_accuracy: 0.7977 - val_loss: 2.0610 - learning_rate: 5.0000e-04
# Epoch 18/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8202 - loss: 1.5077 - val_accuracy: 0.7926 - val_loss: 2.0302 - learning_rate: 5.0000e-04
# Epoch 19/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8199 - loss: 1.4664 - val_accuracy: 0.8035 - val_loss: 1.9871 - learning_rate: 5.0000e-04
# Epoch 20/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8227 - loss: 1.4341 - val_accuracy: 0.7826 - val_loss: 1.9616 - learning_rate: 5.0000e-04
# Epoch 21/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8238 - loss: 1.4104 - val_accuracy: 0.8135 - val_loss: 1.8939 - learning_rate: 5.0000e-04
# Epoch 22/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8308 - loss: 1.3796 - val_accuracy: 0.8294 - val_loss: 1.8485 - learning_rate: 5.0000e-04
# Epoch 23/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8292 - loss: 1.3491 - val_accuracy: 0.8002 - val_loss: 1.8279 - learning_rate: 5.0000e-04
# Epoch 24/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8285 - loss: 1.3163 - val_accuracy: 0.8135 - val_loss: 1.7790 - learning_rate: 5.0000e-04
# Epoch 25/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8374 - loss: 1.2803 - val_accuracy: 0.7960 - val_loss: 1.7299 - learning_rate: 5.0000e-04
# Epoch 26/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8272 - loss: 1.2586 - val_accuracy: 0.7609 - val_loss: 1.7143 - learning_rate: 5.0000e-04
# Epoch 27/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8369 - loss: 1.1897 - val_accuracy: 0.8286 - val_loss: 1.5953 - learning_rate: 5.0000e-04
# Epoch 28/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8270 - loss: 1.1584 - val_accuracy: 0.8161 - val_loss: 1.5655 - learning_rate: 5.0000e-04
# Epoch 29/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8298 - loss: 1.1013 - val_accuracy: 0.8069 - val_loss: 1.5308 - learning_rate: 5.0000e-04
# Epoch 30/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8284 - loss: 1.0536 - val_accuracy: 0.8169 - val_loss: 1.4824 - learning_rate: 5.0000e-04
# Epoch 31/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8311 - loss: 1.0200 - val_accuracy: 0.8110 - val_loss: 1.4534 - learning_rate: 5.0000e-04
# Epoch 32/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8364 - loss: 0.9779 - val_accuracy: 0.8453 - val_loss: 1.4259 - learning_rate: 5.0000e-04
# Epoch 33/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8339 - loss: 0.9546 - val_accuracy: 0.8127 - val_loss: 1.4172 - learning_rate: 5.0000e-04
# Epoch 34/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8279 - loss: 0.9434 - val_accuracy: 0.7851 - val_loss: 1.4105 - learning_rate: 5.0000e-04
# Epoch 35/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8397 - loss: 0.9200 - val_accuracy: 0.7809 - val_loss: 1.3811 - learning_rate: 5.0000e-04
# Epoch 36/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8336 - loss: 0.9128 - val_accuracy: 0.8135 - val_loss: 1.3170 - learning_rate: 5.0000e-04
# Epoch 37/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8325 - loss: 0.9132 - val_accuracy: 0.8554 - val_loss: 1.1978 - learning_rate: 5.0000e-04
# Epoch 38/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8328 - loss: 0.9024 - val_accuracy: 0.8227 - val_loss: 1.2126 - learning_rate: 5.0000e-04
# Epoch 39/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8334 - loss: 0.8973 - val_accuracy: 0.8002 - val_loss: 1.2198 - learning_rate: 5.0000e-04
# Epoch 40/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8323 - loss: 0.8807 - val_accuracy: 0.8253 - val_loss: 1.0997 - learning_rate: 5.0000e-04
# Epoch 41/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8316 - loss: 0.8815 - val_accuracy: 0.8361 - val_loss: 1.0706 - learning_rate: 5.0000e-04
# Epoch 42/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8260 - loss: 0.8859 - val_accuracy: 0.8227 - val_loss: 1.0790 - learning_rate: 5.0000e-04
# Epoch 43/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8300 - loss: 0.8710 - val_accuracy: 0.8186 - val_loss: 1.0367 - learning_rate: 5.0000e-04
# Epoch 44/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8296 - loss: 0.8717 - val_accuracy: 0.8127 - val_loss: 1.0547 - learning_rate: 5.0000e-04
# Epoch 45/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8320 - loss: 0.8613 - val_accuracy: 0.8010 - val_loss: 1.0455 - learning_rate: 5.0000e-04
# Epoch 46/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8259 - loss: 0.8551 - val_accuracy: 0.8478 - val_loss: 0.9634 - learning_rate: 5.0000e-04
# Epoch 47/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8334 - loss: 0.8464 - val_accuracy: 0.8336 - val_loss: 0.9842 - learning_rate: 5.0000e-04
# Epoch 48/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8265 - loss: 0.8517 - val_accuracy: 0.8721 - val_loss: 0.9092 - learning_rate: 5.0000e-04
# Epoch 49/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8296 - loss: 0.8532 - val_accuracy: 0.8428 - val_loss: 0.9289 - learning_rate: 5.0000e-04
# Epoch 50/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8313 - loss: 0.8341 - val_accuracy: 0.8211 - val_loss: 0.9066 - learning_rate: 5.0000e-04
# Epoch 51/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8271 - loss: 0.8377 - val_accuracy: 0.8152 - val_loss: 0.9096 - learning_rate: 5.0000e-04
# Epoch 52/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8332 - loss: 0.8362 - val_accuracy: 0.8027 - val_loss: 0.9203 - learning_rate: 5.0000e-04
# Epoch 53/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8275 - loss: 0.8377 - val_accuracy: 0.8436 - val_loss: 0.8513 - learning_rate: 5.0000e-04
# Epoch 54/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8224 - loss: 0.8427 - val_accuracy: 0.7751 - val_loss: 0.9625 - learning_rate: 5.0000e-04
# Epoch 55/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8351 - loss: 0.8225 - val_accuracy: 0.8344 - val_loss: 0.8307 - learning_rate: 5.0000e-04
# Epoch 56/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8392 - loss: 0.8222 - val_accuracy: 0.7860 - val_loss: 0.9403 - learning_rate: 5.0000e-04
# Epoch 57/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8336 - loss: 0.8241 - val_accuracy: 0.8378 - val_loss: 0.8092 - learning_rate: 5.0000e-04
# Epoch 58/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8371 - loss: 0.8059 - val_accuracy: 0.7818 - val_loss: 0.9206 - learning_rate: 5.0000e-04
# Epoch 59/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8316 - loss: 0.8189 - val_accuracy: 0.8612 - val_loss: 0.7760 - learning_rate: 5.0000e-04
# Epoch 60/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8252 - loss: 0.8246 - val_accuracy: 0.7977 - val_loss: 0.9217 - learning_rate: 5.0000e-04
# Epoch 61/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8280 - loss: 0.8146 - val_accuracy: 0.8177 - val_loss: 0.8537 - learning_rate: 5.0000e-04
# Epoch 62/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8362 - loss: 0.8005 - val_accuracy: 0.8127 - val_loss: 0.8748 - learning_rate: 5.0000e-04
# Epoch 63/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8227 - loss: 0.8295 - val_accuracy: 0.8562 - val_loss: 0.7755 - learning_rate: 5.0000e-04
# Epoch 64/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8285 - loss: 0.8178 - val_accuracy: 0.8453 - val_loss: 0.7495 - learning_rate: 5.0000e-04
# Epoch 65/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8273 - loss: 0.8097 - val_accuracy: 0.8177 - val_loss: 0.8153 - learning_rate: 5.0000e-04
# Epoch 66/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8197 - loss: 0.8350 - val_accuracy: 0.8420 - val_loss: 0.7481 - learning_rate: 5.0000e-04
# Epoch 67/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8302 - loss: 0.8059 - val_accuracy: 0.8411 - val_loss: 0.7634 - learning_rate: 5.0000e-04
# Epoch 68/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8253 - loss: 0.8111 - val_accuracy: 0.8211 - val_loss: 0.8038 - learning_rate: 5.0000e-04
# Epoch 69/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8335 - loss: 0.8034 - val_accuracy: 0.8428 - val_loss: 0.7631 - learning_rate: 5.0000e-04
# Epoch 70/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8378 - loss: 0.7894 - val_accuracy: 0.8386 - val_loss: 0.7809 - learning_rate: 5.0000e-04
# Epoch 71/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8354 - loss: 0.7972 - val_accuracy: 0.8378 - val_loss: 0.7860 - learning_rate: 5.0000e-04
# Epoch 72/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8379 - loss: 0.7846 - val_accuracy: 0.8645 - val_loss: 0.7225 - learning_rate: 1.0000e-04
# Epoch 73/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8443 - loss: 0.7610 - val_accuracy: 0.8696 - val_loss: 0.7154 - learning_rate: 1.0000e-04
# Epoch 74/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8394 - loss: 0.7625 - val_accuracy: 0.8788 - val_loss: 0.7149 - learning_rate: 1.0000e-04
# Epoch 75/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8453 - loss: 0.7471 - val_accuracy: 0.8804 - val_loss: 0.7190 - learning_rate: 1.0000e-04
# Epoch 76/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8534 - loss: 0.7284 - val_accuracy: 0.8687 - val_loss: 0.7351 - learning_rate: 1.0000e-04
# Epoch 77/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8553 - loss: 0.7279 - val_accuracy: 0.8428 - val_loss: 0.7906 - learning_rate: 1.0000e-04
# Epoch 78/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8549 - loss: 0.7150 - val_accuracy: 0.8520 - val_loss: 0.7704 - learning_rate: 1.0000e-04
# Epoch 79/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8558 - loss: 0.7167 - val_accuracy: 0.8604 - val_loss: 0.7809 - learning_rate: 1.0000e-04
# Epoch 80/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8563 - loss: 0.7162 - val_accuracy: 0.8587 - val_loss: 0.7773 - learning_rate: 2.0000e-05
# Epoch 81/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8613 - loss: 0.6971 - val_accuracy: 0.8520 - val_loss: 0.7879 - learning_rate: 2.0000e-05
# Epoch 82/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8586 - loss: 0.6997 - val_accuracy: 0.8436 - val_loss: 0.7935 - learning_rate: 2.0000e-05
# Epoch 83/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8555 - loss: 0.6911 - val_accuracy: 0.8462 - val_loss: 0.7876 - learning_rate: 2.0000e-05
# Epoch 84/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8649 - loss: 0.6855 - val_accuracy: 0.8579 - val_loss: 0.7607 - learning_rate: 2.0000e-05
# Epoch 85/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8578 - loss: 0.6907 - val_accuracy: 0.8637 - val_loss: 0.7437 - learning_rate: 1.0000e-05
# Epoch 86/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8579 - loss: 0.6926 - val_accuracy: 0.8729 - val_loss: 0.7217 - learning_rate: 1.0000e-05
# Epoch 87/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8651 - loss: 0.6793 - val_accuracy: 0.8737 - val_loss: 0.7087 - learning_rate: 1.0000e-05
# Epoch 88/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8614 - loss: 0.6956 - val_accuracy: 0.8754 - val_loss: 0.6954 - learning_rate: 1.0000e-05
# Epoch 89/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8602 - loss: 0.6962 - val_accuracy: 0.8788 - val_loss: 0.6857 - learning_rate: 1.0000e-05
# Epoch 90/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8533 - loss: 0.6921 - val_accuracy: 0.8771 - val_loss: 0.6785 - learning_rate: 1.0000e-05
# Epoch 91/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8624 - loss: 0.6798 - val_accuracy: 0.8746 - val_loss: 0.6752 - learning_rate: 1.0000e-05
# Epoch 92/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8534 - loss: 0.6939 - val_accuracy: 0.8729 - val_loss: 0.6709 - learning_rate: 1.0000e-05
# Epoch 93/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8582 - loss: 0.6823 - val_accuracy: 0.8746 - val_loss: 0.6674 - learning_rate: 1.0000e-05
# Epoch 94/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8551 - loss: 0.6956 - val_accuracy: 0.8721 - val_loss: 0.6679 - learning_rate: 1.0000e-05
# Epoch 95/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8569 - loss: 0.6750 - val_accuracy: 0.8737 - val_loss: 0.6590 - learning_rate: 1.0000e-05
# Epoch 96/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8644 - loss: 0.6716 - val_accuracy: 0.8804 - val_loss: 0.6516 - learning_rate: 1.0000e-05
# Epoch 97/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8580 - loss: 0.6842 - val_accuracy: 0.8838 - val_loss: 0.6466 - learning_rate: 1.0000e-05
# Epoch 98/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8627 - loss: 0.6753 - val_accuracy: 0.8871 - val_loss: 0.6432 - learning_rate: 1.0000e-05
# Epoch 99/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8678 - loss: 0.6719 - val_accuracy: 0.8855 - val_loss: 0.6445 - learning_rate: 1.0000e-05
# Epoch 100/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8595 - loss: 0.6775 - val_accuracy: 0.8838 - val_loss: 0.6397 - learning_rate: 1.0000e-05
# Epoch 101/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8630 - loss: 0.6732 - val_accuracy: 0.8838 - val_loss: 0.6313 - learning_rate: 1.0000e-05
# Epoch 102/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8630 - loss: 0.6753 - val_accuracy: 0.8880 - val_loss: 0.6256 - learning_rate: 1.0000e-05
# Epoch 103/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8685 - loss: 0.6690 - val_accuracy: 0.8871 - val_loss: 0.6198 - learning_rate: 1.0000e-05
# Epoch 104/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8606 - loss: 0.6804 - val_accuracy: 0.8905 - val_loss: 0.6139 - learning_rate: 1.0000e-05
# Epoch 105/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8613 - loss: 0.6703 - val_accuracy: 0.8946 - val_loss: 0.6085 - learning_rate: 1.0000e-05
# Epoch 106/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8695 - loss: 0.6592 - val_accuracy: 0.8972 - val_loss: 0.6153 - learning_rate: 1.0000e-05
# Epoch 107/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8645 - loss: 0.6715 - val_accuracy: 0.8963 - val_loss: 0.6190 - learning_rate: 1.0000e-05
# Epoch 108/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8640 - loss: 0.6732 - val_accuracy: 0.8921 - val_loss: 0.6156 - learning_rate: 1.0000e-05
# Epoch 109/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8641 - loss: 0.6658 - val_accuracy: 0.8938 - val_loss: 0.6096 - learning_rate: 1.0000e-05
# Epoch 110/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8618 - loss: 0.6687 - val_accuracy: 0.8921 - val_loss: 0.6142 - learning_rate: 1.0000e-05
# Epoch 111/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8654 - loss: 0.6612 - val_accuracy: 0.8888 - val_loss: 0.6232 - learning_rate: 1.0000e-05
# Epoch 112/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8644 - loss: 0.6646 - val_accuracy: 0.8838 - val_loss: 0.6340 - learning_rate: 1.0000e-05
# Epoch 113/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8664 - loss: 0.6655 - val_accuracy: 0.8829 - val_loss: 0.6380 - learning_rate: 1.0000e-05
# Epoch 114/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8695 - loss: 0.6573 - val_accuracy: 0.8821 - val_loss: 0.6379 - learning_rate: 1.0000e-05
# Epoch 115/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8655 - loss: 0.6641 - val_accuracy: 0.8855 - val_loss: 0.6305 - learning_rate: 1.0000e-05
# Epoch 116/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8608 - loss: 0.6578 - val_accuracy: 0.8863 - val_loss: 0.6245 - learning_rate: 1.0000e-05
# Epoch 117/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8626 - loss: 0.6705 - val_accuracy: 0.8905 - val_loss: 0.6254 - learning_rate: 1.0000e-05
# Epoch 118/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8601 - loss: 0.6698 - val_accuracy: 0.8946 - val_loss: 0.6144 - learning_rate: 1.0000e-05
# Epoch 119/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8655 - loss: 0.6680 - val_accuracy: 0.8938 - val_loss: 0.6161 - learning_rate: 1.0000e-05
# Epoch 120/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8666 - loss: 0.6550 - val_accuracy: 0.8955 - val_loss: 0.6184 - learning_rate: 1.0000e-05
# Epoch 121/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8633 - loss: 0.6606 - val_accuracy: 0.8921 - val_loss: 0.6194 - learning_rate: 1.0000e-05
# Epoch 122/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8712 - loss: 0.6507 - val_accuracy: 0.8846 - val_loss: 0.6260 - learning_rate: 1.0000e-05
# Epoch 123/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8582 - loss: 0.6659 - val_accuracy: 0.8871 - val_loss: 0.6181 - learning_rate: 1.0000e-05
# Epoch 124/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8649 - loss: 0.6618 - val_accuracy: 0.8880 - val_loss: 0.6147 - learning_rate: 1.0000e-05
# Epoch 125/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8642 - loss: 0.6640 - val_accuracy: 0.8880 - val_loss: 0.6064 - learning_rate: 1.0000e-05
# Epoch 126/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8615 - loss: 0.6522 - val_accuracy: 0.8863 - val_loss: 0.6068 - learning_rate: 1.0000e-05
# Epoch 127/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8697 - loss: 0.6452 - val_accuracy: 0.8896 - val_loss: 0.6035 - learning_rate: 1.0000e-05
# Epoch 128/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8691 - loss: 0.6513 - val_accuracy: 0.8863 - val_loss: 0.6037 - learning_rate: 1.0000e-05
# Epoch 129/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8608 - loss: 0.6641 - val_accuracy: 0.8863 - val_loss: 0.6041 - learning_rate: 1.0000e-05
# Epoch 130/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8660 - loss: 0.6597 - val_accuracy: 0.8829 - val_loss: 0.6110 - learning_rate: 1.0000e-05
# Epoch 131/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8724 - loss: 0.6443 - val_accuracy: 0.8838 - val_loss: 0.6108 - learning_rate: 1.0000e-05
# Epoch 132/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8667 - loss: 0.6609 - val_accuracy: 0.8871 - val_loss: 0.6020 - learning_rate: 1.0000e-05
# Epoch 133/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8628 - loss: 0.6650 - val_accuracy: 0.8896 - val_loss: 0.5991 - learning_rate: 1.0000e-05
# Epoch 134/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8688 - loss: 0.6584 - val_accuracy: 0.8913 - val_loss: 0.6021 - learning_rate: 1.0000e-05
# Epoch 135/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8646 - loss: 0.6538 - val_accuracy: 0.8921 - val_loss: 0.6055 - learning_rate: 1.0000e-05
# Epoch 136/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8621 - loss: 0.6640 - val_accuracy: 0.8930 - val_loss: 0.6026 - learning_rate: 1.0000e-05
# Final validation accuracy: 89.72%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
print(model_filename)
# Out:
# NoPainNoTrain89.72.keras

# %%
# Re-load the model after transfer learning
ft_model = tf.keras.models.load_model('NoPainNoTrain89.72.keras')

# Display a summary of the model architecture
# ft_model.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
# tfk.utils.plot_model(ft_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %%
# Set all EfficientNetB0 layers as non-trainable
for layer in ft_model.get_layer('convnext_small').layers:
    layer.trainable = False

# Enable training only for Conv2D and DepthwiseConv2D layers
for i, layer in enumerate(ft_model.get_layer('convnext_small').layers):
    if isinstance(layer, tf.keras.layers.Conv2D) or isinstance(layer, tf.keras.layers.DepthwiseConv2D):
        layer.trainable = True
        print(i, layer.name, type(layer).__name__, layer.trainable)
# Out:
# 3 convnext_small_stage_0_block_0_depthwise_conv Conv2D True
# 10 convnext_small_stage_0_block_1_depthwise_conv Conv2D True
# 17 convnext_small_stage_0_block_2_depthwise_conv Conv2D True
# 25 convnext_small_stage_1_block_0_depthwise_conv Conv2D True
# 32 convnext_small_stage_1_block_1_depthwise_conv Conv2D True
# 39 convnext_small_stage_1_block_2_depthwise_conv Conv2D True
# 47 convnext_small_stage_2_block_0_depthwise_conv Conv2D True
# 54 convnext_small_stage_2_block_1_depthwise_conv Conv2D True
# 61 convnext_small_stage_2_block_2_depthwise_conv Conv2D True
# 68 convnext_small_stage_2_block_3_depthwise_conv Conv2D True
# 75 convnext_small_stage_2_block_4_depthwise_conv Conv2D True
# 82 convnext_small_stage_2_block_5_depthwise_conv Conv2D True
# 89 convnext_small_stage_2_block_6_depthwise_conv Conv2D True
# 96 convnext_small_stage_2_block_7_depthwise_conv Conv2D True
# 103 convnext_small_stage_2_block_8_depthwise_conv Conv2D True
# 110 convnext_small_stage_2_block_9_depthwise_conv Conv2D True
# 117 convnext_small_stage_2_block_10_depthwise_conv Conv2D True
# 124 convnext_small_stage_2_block_11_depthwise_conv Conv2D True
# 131 convnext_small_stage_2_block_12_depthwise_conv Conv2D True
# 138 convnext_small_stage_2_block_13_depthwise_conv Conv2D True
# 145 convnext_small_stage_2_block_14_depthwise_conv Conv2D True
# 152 convnext_small_stage_2_block_15_depthwise_conv Conv2D True
# 159 convnext_small_stage_2_block_16_depthwise_conv Conv2D True
# 166 convnext_small_stage_2_block_17_depthwise_conv Conv2D True
# 173 convnext_small_stage_2_block_18_depthwise_conv Conv2D True
# 180 convnext_small_stage_2_block_19_depthwise_conv Conv2D True
# 187 convnext_small_stage_2_block_20_depthwise_conv Conv2D True
# 194 convnext_small_stage_2_block_21_depthwise_conv Conv2D True
# 201 convnext_small_stage_2_block_22_depthwise_conv Conv2D True
# 208 convnext_small_stage_2_block_23_depthwise_conv Conv2D True
# 215 convnext_small_stage_2_block_24_depthwise_conv Conv2D True
# 222 convnext_small_stage_2_block_25_depthwise_conv Conv2D True
# 229 convnext_small_stage_2_block_26_depthwise_conv Conv2D True
# 237 convnext_small_stage_3_block_0_depthwise_conv Conv2D True
# 244 convnext_small_stage_3_block_1_depthwise_conv Conv2D True
# 251 convnext_small_stage_3_block_2_depthwise_conv Conv2D True

# %%
# Set the number of layers to freeze

# Calcola i parametri totali
trainable_params = sum(
    tf.reduce_sum([tf.size(var) for var in layer.trainable_weights]).numpy()
    for layer in ft_model.get_layer('convnext_small').layers
)
target_params = 0.9 * trainable_params  # Il 10% dei parametri totali

# Trova N
cumulative_params = 0
N = 0
for i, layer in enumerate(ft_model.get_layer('convnext_small').layers):
    cumulative_params += sum(tf.size(var).numpy() for var in layer.trainable_weights)
    if cumulative_params >= target_params:
        N = i
        break

print(N)

# Set the first N layers as non-trainable
for i, layer in enumerate(ft_model.get_layer('convnext_small').layers[:N]):
    layer.trainable = False

# Print layer indices, names, and trainability status
for i, layer in enumerate(ft_model.get_layer('convnext_small').layers):
    print(i, layer.name, layer.trainable)

# Display a summary of the model architecture
 #ft_model.summary(expand_nested=False, show_trainable=True)


# Display model architecture with layer shapes and trainable parameters
# tfk.utils.plot_model(ft_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# 244
# 0 input_layer False
# 1 convnext_small_prestem_normalization False
# 2 convnext_small_stem False
# 3 convnext_small_stage_0_block_0_depthwise_conv False
# 4 convnext_small_stage_0_block_0_layernorm False
# 5 convnext_small_stage_0_block_0_pointwise_conv_1 False
# 6 convnext_small_stage_0_block_0_gelu False
# 7 convnext_small_stage_0_block_0_pointwise_conv_2 False
# 8 convnext_small_stage_0_block_0_layer_scale False
# 9 convnext_small_stage_0_block_0_identity False
# 10 convnext_small_stage_0_block_1_depthwise_conv False
# 11 convnext_small_stage_0_block_1_layernorm False
# 12 convnext_small_stage_0_block_1_pointwise_conv_1 False
# 13 convnext_small_stage_0_block_1_gelu False
# 14 convnext_small_stage_0_block_1_pointwise_conv_2 False
# 15 convnext_small_stage_0_block_1_layer_scale False
# 16 convnext_small_stage_0_block_1_identity False
# 17 convnext_small_stage_0_block_2_depthwise_conv False
# 18 convnext_small_stage_0_block_2_layernorm False
# 19 convnext_small_stage_0_block_2_pointwise_conv_1 False
# 20 convnext_small_stage_0_block_2_gelu False
# 21 convnext_small_stage_0_block_2_pointwise_conv_2 False
# 22 convnext_small_stage_0_block_2_layer_scale False
# 23 convnext_small_stage_0_block_2_identity False
# 24 convnext_small_downsampling_block_0 False
# 25 convnext_small_stage_1_block_0_depthwise_conv False
# 26 convnext_small_stage_1_block_0_layernorm False
# 27 convnext_small_stage_1_block_0_pointwise_conv_1 False
# 28 convnext_small_stage_1_block_0_gelu False
# 29 convnext_small_stage_1_block_0_pointwise_conv_2 False
# 30 convnext_small_stage_1_block_0_layer_scale False
# 31 convnext_small_stage_1_block_0_identity False
# 32 convnext_small_stage_1_block_1_depthwise_conv False
# 33 convnext_small_stage_1_block_1_layernorm False
# 34 convnext_small_stage_1_block_1_pointwise_conv_1 False
# 35 convnext_small_stage_1_block_1_gelu False
# 36 convnext_small_stage_1_block_1_pointwise_conv_2 False
# 37 convnext_small_stage_1_block_1_layer_scale False
# 38 convnext_small_stage_1_block_1_identity False
# 39 convnext_small_stage_1_block_2_depthwise_conv False
# 40 convnext_small_stage_1_block_2_layernorm False
# 41 convnext_small_stage_1_block_2_pointwise_conv_1 False
# 42 convnext_small_stage_1_block_2_gelu False
# 43 convnext_small_stage_1_block_2_pointwise_conv_2 False
# 44 convnext_small_stage_1_block_2_layer_scale False
# 45 convnext_small_stage_1_block_2_identity False
# 46 convnext_small_downsampling_block_1 False
# 47 convnext_small_stage_2_block_0_depthwise_conv False
# 48 convnext_small_stage_2_block_0_layernorm False
# 49 convnext_small_stage_2_block_0_pointwise_conv_1 False
# 50 convnext_small_stage_2_block_0_gelu False
# 51 convnext_small_stage_2_block_0_pointwise_conv_2 False
# 52 convnext_small_stage_2_block_0_layer_scale False
# 53 convnext_small_stage_2_block_0_identity False
# 54 convnext_small_stage_2_block_1_depthwise_conv False
# 55 convnext_small_stage_2_block_1_layernorm False
# 56 convnext_small_stage_2_block_1_pointwise_conv_1 False
# 57 convnext_small_stage_2_block_1_gelu False
# 58 convnext_small_stage_2_block_1_pointwise_conv_2 False
# 59 convnext_small_stage_2_block_1_layer_scale False
# 60 convnext_small_stage_2_block_1_identity False
# 61 convnext_small_stage_2_block_2_depthwise_conv False
# 62 convnext_small_stage_2_block_2_layernorm False
# 63 convnext_small_stage_2_block_2_pointwise_conv_1 False
# 64 convnext_small_stage_2_block_2_gelu False
# 65 convnext_small_stage_2_block_2_pointwise_conv_2 False
# 66 convnext_small_stage_2_block_2_layer_scale False
# 67 convnext_small_stage_2_block_2_identity False
# 68 convnext_small_stage_2_block_3_depthwise_conv False
# 69 convnext_small_stage_2_block_3_layernorm False
# 70 convnext_small_stage_2_block_3_pointwise_conv_1 False
# 71 convnext_small_stage_2_block_3_gelu False
# 72 convnext_small_stage_2_block_3_pointwise_conv_2 False
# 73 convnext_small_stage_2_block_3_layer_scale False
# 74 convnext_small_stage_2_block_3_identity False
# 75 convnext_small_stage_2_block_4_depthwise_conv False
# 76 convnext_small_stage_2_block_4_layernorm False
# 77 convnext_small_stage_2_block_4_pointwise_conv_1 False
# 78 convnext_small_stage_2_block_4_gelu False
# 79 convnext_small_stage_2_block_4_pointwise_conv_2 False
# 80 convnext_small_stage_2_block_4_layer_scale False
# 81 convnext_small_stage_2_block_4_identity False
# 82 convnext_small_stage_2_block_5_depthwise_conv False
# 83 convnext_small_stage_2_block_5_layernorm False
# 84 convnext_small_stage_2_block_5_pointwise_conv_1 False
# 85 convnext_small_stage_2_block_5_gelu False
# 86 convnext_small_stage_2_block_5_pointwise_conv_2 False
# 87 convnext_small_stage_2_block_5_layer_scale False
# 88 convnext_small_stage_2_block_5_identity False
# 89 convnext_small_stage_2_block_6_depthwise_conv False
# 90 convnext_small_stage_2_block_6_layernorm False
# 91 convnext_small_stage_2_block_6_pointwise_conv_1 False
# 92 convnext_small_stage_2_block_6_gelu False
# 93 convnext_small_stage_2_block_6_pointwise_conv_2 False
# 94 convnext_small_stage_2_block_6_layer_scale False
# 95 convnext_small_stage_2_block_6_identity False
# 96 convnext_small_stage_2_block_7_depthwise_conv False
# 97 convnext_small_stage_2_block_7_layernorm False
# 98 convnext_small_stage_2_block_7_pointwise_conv_1 False
# 99 convnext_small_stage_2_block_7_gelu False
# 100 convnext_small_stage_2_block_7_pointwise_conv_2 False
# 101 convnext_small_stage_2_block_7_layer_scale False
# 102 convnext_small_stage_2_block_7_identity False
# 103 convnext_small_stage_2_block_8_depthwise_conv False
# 104 convnext_small_stage_2_block_8_layernorm False
# 105 convnext_small_stage_2_block_8_pointwise_conv_1 False
# 106 convnext_small_stage_2_block_8_gelu False
# 107 convnext_small_stage_2_block_8_pointwise_conv_2 False
# 108 convnext_small_stage_2_block_8_layer_scale False
# 109 convnext_small_stage_2_block_8_identity False
# 110 convnext_small_stage_2_block_9_depthwise_conv False
# 111 convnext_small_stage_2_block_9_layernorm False
# 112 convnext_small_stage_2_block_9_pointwise_conv_1 False
# 113 convnext_small_stage_2_block_9_gelu False
# 114 convnext_small_stage_2_block_9_pointwise_conv_2 False
# 115 convnext_small_stage_2_block_9_layer_scale False
# 116 convnext_small_stage_2_block_9_identity False
# 117 convnext_small_stage_2_block_10_depthwise_conv False
# 118 convnext_small_stage_2_block_10_layernorm False
# 119 convnext_small_stage_2_block_10_pointwise_conv_1 False
# 120 convnext_small_stage_2_block_10_gelu False
# 121 convnext_small_stage_2_block_10_pointwise_conv_2 False
# 122 convnext_small_stage_2_block_10_layer_scale False
# 123 convnext_small_stage_2_block_10_identity False
# 124 convnext_small_stage_2_block_11_depthwise_conv False
# 125 convnext_small_stage_2_block_11_layernorm False
# 126 convnext_small_stage_2_block_11_pointwise_conv_1 False
# 127 convnext_small_stage_2_block_11_gelu False
# 128 convnext_small_stage_2_block_11_pointwise_conv_2 False
# 129 convnext_small_stage_2_block_11_layer_scale False
# 130 convnext_small_stage_2_block_11_identity False
# 131 convnext_small_stage_2_block_12_depthwise_conv False
# 132 convnext_small_stage_2_block_12_layernorm False
# 133 convnext_small_stage_2_block_12_pointwise_conv_1 False
# 134 convnext_small_stage_2_block_12_gelu False
# 135 convnext_small_stage_2_block_12_pointwise_conv_2 False
# 136 convnext_small_stage_2_block_12_layer_scale False
# 137 convnext_small_stage_2_block_12_identity False
# 138 convnext_small_stage_2_block_13_depthwise_conv False
# 139 convnext_small_stage_2_block_13_layernorm False
# 140 convnext_small_stage_2_block_13_pointwise_conv_1 False
# 141 convnext_small_stage_2_block_13_gelu False
# 142 convnext_small_stage_2_block_13_pointwise_conv_2 False
# 143 convnext_small_stage_2_block_13_layer_scale False
# 144 convnext_small_stage_2_block_13_identity False
# 145 convnext_small_stage_2_block_14_depthwise_conv False
# 146 convnext_small_stage_2_block_14_layernorm False
# 147 convnext_small_stage_2_block_14_pointwise_conv_1 False
# 148 convnext_small_stage_2_block_14_gelu False
# 149 convnext_small_stage_2_block_14_pointwise_conv_2 False
# 150 convnext_small_stage_2_block_14_layer_scale False
# 151 convnext_small_stage_2_block_14_identity False
# 152 convnext_small_stage_2_block_15_depthwise_conv False
# 153 convnext_small_stage_2_block_15_layernorm False
# 154 convnext_small_stage_2_block_15_pointwise_conv_1 False
# 155 convnext_small_stage_2_block_15_gelu False
# 156 convnext_small_stage_2_block_15_pointwise_conv_2 False
# 157 convnext_small_stage_2_block_15_layer_scale False
# 158 convnext_small_stage_2_block_15_identity False
# 159 convnext_small_stage_2_block_16_depthwise_conv False
# 160 convnext_small_stage_2_block_16_layernorm False
# 161 convnext_small_stage_2_block_16_pointwise_conv_1 False
# 162 convnext_small_stage_2_block_16_gelu False
# 163 convnext_small_stage_2_block_16_pointwise_conv_2 False
# 164 convnext_small_stage_2_block_16_layer_scale False
# 165 convnext_small_stage_2_block_16_identity False
# 166 convnext_small_stage_2_block_17_depthwise_conv False
# 167 convnext_small_stage_2_block_17_layernorm False
# 168 convnext_small_stage_2_block_17_pointwise_conv_1 False
# 169 convnext_small_stage_2_block_17_gelu False
# 170 convnext_small_stage_2_block_17_pointwise_conv_2 False
# 171 convnext_small_stage_2_block_17_layer_scale False
# 172 convnext_small_stage_2_block_17_identity False
# 173 convnext_small_stage_2_block_18_depthwise_conv False
# 174 convnext_small_stage_2_block_18_layernorm False
# 175 convnext_small_stage_2_block_18_pointwise_conv_1 False
# 176 convnext_small_stage_2_block_18_gelu False
# 177 convnext_small_stage_2_block_18_pointwise_conv_2 False
# 178 convnext_small_stage_2_block_18_layer_scale False
# 179 convnext_small_stage_2_block_18_identity False
# 180 convnext_small_stage_2_block_19_depthwise_conv False
# 181 convnext_small_stage_2_block_19_layernorm False
# 182 convnext_small_stage_2_block_19_pointwise_conv_1 False
# 183 convnext_small_stage_2_block_19_gelu False
# 184 convnext_small_stage_2_block_19_pointwise_conv_2 False
# 185 convnext_small_stage_2_block_19_layer_scale False
# 186 convnext_small_stage_2_block_19_identity False
# 187 convnext_small_stage_2_block_20_depthwise_conv False
# 188 convnext_small_stage_2_block_20_layernorm False
# 189 convnext_small_stage_2_block_20_pointwise_conv_1 False
# 190 convnext_small_stage_2_block_20_gelu False
# 191 convnext_small_stage_2_block_20_pointwise_conv_2 False
# 192 convnext_small_stage_2_block_20_layer_scale False
# 193 convnext_small_stage_2_block_20_identity False
# 194 convnext_small_stage_2_block_21_depthwise_conv False
# 195 convnext_small_stage_2_block_21_layernorm False
# 196 convnext_small_stage_2_block_21_pointwise_conv_1 False
# 197 convnext_small_stage_2_block_21_gelu False
# 198 convnext_small_stage_2_block_21_pointwise_conv_2 False
# 199 convnext_small_stage_2_block_21_layer_scale False
# 200 convnext_small_stage_2_block_21_identity False
# 201 convnext_small_stage_2_block_22_depthwise_conv False
# 202 convnext_small_stage_2_block_22_layernorm False
# 203 convnext_small_stage_2_block_22_pointwise_conv_1 False
# 204 convnext_small_stage_2_block_22_gelu False
# 205 convnext_small_stage_2_block_22_pointwise_conv_2 False
# 206 convnext_small_stage_2_block_22_layer_scale False
# 207 convnext_small_stage_2_block_22_identity False
# 208 convnext_small_stage_2_block_23_depthwise_conv False
# 209 convnext_small_stage_2_block_23_layernorm False
# 210 convnext_small_stage_2_block_23_pointwise_conv_1 False
# 211 convnext_small_stage_2_block_23_gelu False
# 212 convnext_small_stage_2_block_23_pointwise_conv_2 False
# 213 convnext_small_stage_2_block_23_layer_scale False
# 214 convnext_small_stage_2_block_23_identity False
# 215 convnext_small_stage_2_block_24_depthwise_conv False
# 216 convnext_small_stage_2_block_24_layernorm False
# 217 convnext_small_stage_2_block_24_pointwise_conv_1 False
# 218 convnext_small_stage_2_block_24_gelu False
# 219 convnext_small_stage_2_block_24_pointwise_conv_2 False
# 220 convnext_small_stage_2_block_24_layer_scale False
# 221 convnext_small_stage_2_block_24_identity False
# 222 convnext_small_stage_2_block_25_depthwise_conv False
# 223 convnext_small_stage_2_block_25_layernorm False
# 224 convnext_small_stage_2_block_25_pointwise_conv_1 False
# 225 convnext_small_stage_2_block_25_gelu False
# 226 convnext_small_stage_2_block_25_pointwise_conv_2 False
# 227 convnext_small_stage_2_block_25_layer_scale False
# 228 convnext_small_stage_2_block_25_identity False
# 229 convnext_small_stage_2_block_26_depthwise_conv False
# 230 convnext_small_stage_2_block_26_layernorm False
# 231 convnext_small_stage_2_block_26_pointwise_conv_1 False
# 232 convnext_small_stage_2_block_26_gelu False
# 233 convnext_small_stage_2_block_26_pointwise_conv_2 False
# 234 convnext_small_stage_2_block_26_layer_scale False
# 235 convnext_small_stage_2_block_26_identity False
# 236 convnext_small_downsampling_block_2 False
# 237 convnext_small_stage_3_block_0_depthwise_conv False
# 238 convnext_small_stage_3_block_0_layernorm False
# 239 convnext_small_stage_3_block_0_pointwise_conv_1 False
# 240 convnext_small_stage_3_block_0_gelu False
# 241 convnext_small_stage_3_block_0_pointwise_conv_2 False
# 242 convnext_small_stage_3_block_0_layer_scale False
# 243 convnext_small_stage_3_block_0_identity False
# 244 convnext_small_stage_3_block_1_depthwise_conv True
# 245 convnext_small_stage_3_block_1_layernorm False
# 246 convnext_small_stage_3_block_1_pointwise_conv_1 False
# 247 convnext_small_stage_3_block_1_gelu False
# 248 convnext_small_stage_3_block_1_pointwise_conv_2 False
# 249 convnext_small_stage_3_block_1_layer_scale False
# 250 convnext_small_stage_3_block_1_identity False
# 251 convnext_small_stage_3_block_2_depthwise_conv True
# 252 convnext_small_stage_3_block_2_layernorm False
# 253 convnext_small_stage_3_block_2_pointwise_conv_1 False
# 254 convnext_small_stage_3_block_2_gelu False
# 255 convnext_small_stage_3_block_2_pointwise_conv_2 False
# 256 convnext_small_stage_3_block_2_layer_scale False
# 257 convnext_small_stage_3_block_2_identity False
# 258 global_max_pooling2d False
# 259 layer_normalization False

# %%
# Compile the model
loss =  losses.CategoricalCrossentropy()
optimizer = tf.keras.optimizers.Lion(learning_rate = 1e-4)
metrics = ['accuracy']
ft_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Fine-tune the model
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Metric to monitor
    factor=0.1,          # Factor to reduce learning rate by (0.1 means divide by 10)
    patience=5,          # Number of epochs to wait before reducing
    min_lr=5e-6       # Minimum learning rate
)

# Create an EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=15,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [reduce_lr,early_stopping]

ft_history = ft_model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    callbacks = callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'NoPainNoTrainFT'+str(final_val_accuracy)+'.keras'
ft_model.save(model_filename)

# Delete the model to free up resources
del ft_model
# Out:
# Epoch 1/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - accuracy: 0.8609 - loss: 0.6625 - val_accuracy: 0.8963 - val_loss: 0.6112 - learning_rate: 1.0000e-04
# Epoch 2/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.8623 - loss: 0.6634 - val_accuracy: 0.8938 - val_loss: 0.6179 - learning_rate: 1.0000e-04
# Epoch 3/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8636 - loss: 0.6542 - val_accuracy: 0.8921 - val_loss: 0.6160 - learning_rate: 1.0000e-04
# Epoch 4/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8675 - loss: 0.6469 - val_accuracy: 0.8880 - val_loss: 0.6102 - learning_rate: 1.0000e-04
# Epoch 5/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8608 - loss: 0.6525 - val_accuracy: 0.8921 - val_loss: 0.5892 - learning_rate: 1.0000e-04
# Epoch 6/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8694 - loss: 0.6436 - val_accuracy: 0.8946 - val_loss: 0.5818 - learning_rate: 1.0000e-04
# Epoch 7/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8700 - loss: 0.6333 - val_accuracy: 0.8796 - val_loss: 0.6073 - learning_rate: 1.0000e-04
# Epoch 8/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8709 - loss: 0.6363 - val_accuracy: 0.8880 - val_loss: 0.5965 - learning_rate: 1.0000e-04
# Epoch 9/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8686 - loss: 0.6283 - val_accuracy: 0.8696 - val_loss: 0.6214 - learning_rate: 1.0000e-04
# Epoch 10/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.8693 - loss: 0.6373 - val_accuracy: 0.8938 - val_loss: 0.5886 - learning_rate: 1.0000e-04
# Epoch 11/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8722 - loss: 0.6238 - val_accuracy: 0.9030 - val_loss: 0.5854 - learning_rate: 1.0000e-04
# Epoch 12/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8752 - loss: 0.6192 - val_accuracy: 0.8997 - val_loss: 0.5781 - learning_rate: 1.0000e-05
# Epoch 13/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8736 - loss: 0.6129 - val_accuracy: 0.8921 - val_loss: 0.5819 - learning_rate: 1.0000e-05
# Epoch 14/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8776 - loss: 0.6150 - val_accuracy: 0.8921 - val_loss: 0.5798 - learning_rate: 1.0000e-05
# Epoch 15/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8760 - loss: 0.6146 - val_accuracy: 0.8888 - val_loss: 0.5819 - learning_rate: 1.0000e-05
# Epoch 16/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8718 - loss: 0.6148 - val_accuracy: 0.8829 - val_loss: 0.5849 - learning_rate: 1.0000e-05
# Epoch 17/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8856 - loss: 0.5988 - val_accuracy: 0.8804 - val_loss: 0.5842 - learning_rate: 1.0000e-05
# Epoch 18/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.8802 - loss: 0.6037 - val_accuracy: 0.8846 - val_loss: 0.5787 - learning_rate: 5.0000e-06
# Epoch 19/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8748 - loss: 0.6156 - val_accuracy: 0.8863 - val_loss: 0.5748 - learning_rate: 5.0000e-06
# Epoch 20/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8807 - loss: 0.6031 - val_accuracy: 0.8905 - val_loss: 0.5701 - learning_rate: 5.0000e-06
# Epoch 21/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8732 - loss: 0.6090 - val_accuracy: 0.8913 - val_loss: 0.5683 - learning_rate: 5.0000e-06
# Epoch 22/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8756 - loss: 0.6079 - val_accuracy: 0.8921 - val_loss: 0.5656 - learning_rate: 5.0000e-06
# Epoch 23/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8766 - loss: 0.6070 - val_accuracy: 0.8946 - val_loss: 0.5604 - learning_rate: 5.0000e-06
# Epoch 24/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8758 - loss: 0.5999 - val_accuracy: 0.8963 - val_loss: 0.5581 - learning_rate: 5.0000e-06
# Epoch 25/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.8761 - loss: 0.6011 - val_accuracy: 0.8946 - val_loss: 0.5551 - learning_rate: 5.0000e-06
# Epoch 26/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8830 - loss: 0.5965 - val_accuracy: 0.8988 - val_loss: 0.5505 - learning_rate: 5.0000e-06
# Final validation accuracy: 90.3%

# %%
print(model_filename)
# Out:
# NoPainNoTrainFT90.3.keras

# %% [markdown]
# ## 📊 Prepare Your Submission
#
# To prepare your submission, create a `.zip` file that includes all the necessary code to run your model. It **must** include a `model.py` file with the following class:
#
# ```python
# # file: model.py
# class Model:
#     def __init__(self):
#         """Initialize the internal state of the model."""
#
#     def predict(self, X):
#         """Return a numpy array with the labels corresponding to the input X."""
# ```
#
# The next cell shows an example implementation of the `model.py` file, which includes loading model weights from the `weights.keras` file and conducting predictions on provided input data. The `.zip` file is created and downloaded in the last notebook cell.
#
# ❗ Feel free to modify the method implementations to better fit your specific requirements, but please ensure that the class name and method interfaces remain unchanged.

# %%
# %%writefile model.py
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.

        The following is an example loading the weights of a pre-trained
        model.
        """
        self.neural_network = tfk.models.load_model('NoPainNoTrainFT95.09.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must no be one-hot
        encoded.

        The following is an example of a prediction from the pre-trained model
        loaded in the __init__ method.
        """
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Overwriting model.py

# %%
from datetime import datetime
filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py NoPainNoTrainFT95.09.keras

from google.colab import files
files.download(filename)
# Out:
#   adding: model.py (deflated 55%)
#   adding: NoPainNoTrainFT95.09.keras (deflated 9%)
